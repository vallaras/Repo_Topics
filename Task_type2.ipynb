# %%
import requests
import json
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import datetime

# %%
api1=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/list', verify=False)

# %%
api2=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/list', verify=False)

# %%
ae_str=json.loads(api1.text)

# %%
cm_str1=json.loads(api2.text)

# %%
Sub_id_ae=pd.DataFrame(ae_str)
print(Sub_id_ae.head())
print()
Sub_ID_cm=pd.DataFrame(cm_str1)
print(Sub_ID_cm.head())
# Out:
#     status    data                            request_id
# 0  success   76809  0bd077f5-5223-4349-bd11-e631c2b0c2c7
# 1  success  105792  0bd077f5-5223-4349-bd11-e631c2b0c2c7
# 2  success  117691  0bd077f5-5223-4349-bd11-e631c2b0c2c7
# 3  success  120205  0bd077f5-5223-4349-bd11-e631c2b0c2c7
# 4  success  130301  0bd077f5-5223-4349-bd11-e631c2b0c2c7
#
#     status    data                            request_id
# 0  success   76809  f806a21d-aa36-44dc-a1b1-33aa8e61865c
# 1  success  130301  f806a21d-aa36-44dc-a1b1-33aa8e61865c
# 2  success  132645  f806a21d-aa36-44dc-a1b1-33aa8e61865c
# 3  success  138700  f806a21d-aa36-44dc-a1b1-33aa8e61865c
# 4  success  166621  f806a21d-aa36-44dc-a1b1-33aa8e61865c

# %%
Sub_id_ae['data']
# Out:
# 0         76809
# 1        105792
# 2        117691
# 3        120205
# 4        130301
#          ...
# 723    17954820
# 724    17956076
# 725    18042999
# 726    18282353
# 727    18291148
# Name: data, Length: 728, dtype: int64

# %%
c=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/105792/list',verify=False)
d=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/105792/list',verify=False)

# %%
op=json.loads(c.text)
pd.DataFrame(op)
# Out:
#      status                                               data  \
# 0   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 1   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 2   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 3   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 4   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# ..      ...                                                ...
# 61  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 62  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 63  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 64  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 65  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
#
#                               request_id
# 0   b813575b-3539-471d-9457-78ef6338aeb4
# 1   b813575b-3539-471d-9457-78ef6338aeb4
# 2   b813575b-3539-471d-9457-78ef6338aeb4
# 3   b813575b-3539-471d-9457-78ef6338aeb4
# 4   b813575b-3539-471d-9457-78ef6338aeb4
# ..                                   ...
# 61  b813575b-3539-471d-9457-78ef6338aeb4
# 62  b813575b-3539-471d-9457-78ef6338aeb4
# 63  b813575b-3539-471d-9457-78ef6338aeb4
# 64  b813575b-3539-471d-9457-78ef6338aeb4
# 65  b813575b-3539-471d-9457-78ef6338aeb4
#
# [66 rows x 3 columns]

# %%
appended_data = []
for i in Sub_id_ae['data']:
    c=requests.get(f'https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/{i}/list', verify=False)
    output3=json.loads(c.text)
    appended_data.append(output3)
Task1_ae=pd.DataFrame(appended_data)

# %%
Task1_ae
# Out:
#       status                                               data  \
# 0    success  [{'studyid': 'StudyHack', 'siteid': 5173, 'sub...
# 1    success  [{'studyid': 'StudyHack', 'siteid': 5538, 'sub...
# 2    success  [{'studyid': 'StudyHack', 'siteid': 5160, 'sub...
# 3    success  [{'studyid': 'StudyHack', 'siteid': 5160, 'sub...
# 4    success  [{'studyid': 'StudyHack', 'siteid': 5535, 'sub...
# ..       ...                                                ...
# 723  success  [{'studyid': 'StudyHack', 'siteid': 5045, 'sub...
# 724  success  [{'studyid': 'StudyHack', 'siteid': 5045, 'sub...
# 725  success  [{'studyid': 'StudyHack', 'siteid': 5303, 'sub...
# 726  success  [{'studyid': 'StudyHack', 'siteid': 5018, 'sub...
# 727  success  [{'studyid': 'StudyHack', 'siteid': 5018, 'sub...
#
#                                request_id
# 0    596d0051-1293-48a2-bc98-17943e6ec0cf
# 1    4a12be4c-0769-443b-862f-c8380076aff4
# 2    50f245bd-e34a-46bb-a5c3-4bd43d15acb2
# 3    a5bc91a6-eb6b-441d-846c-a34884ead23c
# 4    80bd2645-4d21-46bd-aab0-5609cd8bbba4
# ..                                    ...
# 723  b9f20791-cc88-4a25-ad15-5cdaf1ffeb30
# 724  4a523a85-47a0-4ba2-8f20-d5c99f46f86a
# 725  82b4f99d-57d9-4f11-a767-6f29b73a1c58
# 726  4992d6ef-d967-4c94-9cc5-0e68bcaead7a
# 727  147eeb55-8089-4d81-b8e1-40eeb7c42f83
#
# [728 rows x 3 columns]

# %%
ae_names=[]
for x in Task1_ae['data']:
    n=x[0]
    ae_names.append(n)

# %%
ae=pd.DataFrame(ae_names)
ae
# Out:
#        studyid  siteid    subjid  subjectid  visitindex visitnam formname  \
# 0    StudyHack    5173  51735001      76809           1     AECM    AE202
# 1    StudyHack    5538  55385001     105792           1     AECM    AE202
# 2    StudyHack    5160  51605001     117691           1     AECM    AE202
# 3    StudyHack    5160  51605002     120205           1     AECM  AE202_2
# 4    StudyHack    5535  55355001     130301           1     AECM    AE202
# ..         ...     ...       ...        ...         ...      ...      ...
# 723  StudyHack    5045  50455013   17954820           1     AECM    AE202
# 724  StudyHack    5045  50455014   17956076           1     AECM    AE202
# 725  StudyHack    5303  53035001   18042999           1     AECM    AE202
# 726  StudyHack    5018  50185007   18282353           1     AECM    AE202
# 727  StudyHack    5018  50185008   18291148           1     AECM    AE202
#
#      formid  formidx     formindex  ... aeacn3_c            aeacn3 aeacn3_1_c  \
# 0     38768        4  5.550000e+14  ...      NaN                          2.0
# 1     38768       43  5.520000e+14  ...      NaN                          2.0
# 2     38768       16  5.510000e+14  ...      NaN                          2.0
# 3     35537        1  5.580000e+14  ...      NaN                          NaN
# 4     38768        1  5.550000e+14  ...      2.0  DOSE NOT CHANGED        NaN
# ..      ...      ...           ...  ...      ...               ...        ...
# 723   38768        2  6.100000e+14  ...      NaN                          2.0
# 724   38768        1  6.100000e+14  ...      NaN                          2.0
# 725   38768        9  6.020000e+14  ...      NaN                          2.0
# 726   38768       11  6.030000e+14  ...      2.0  DOSE NOT CHANGED        NaN
# 727   38768       12  6.030000e+14  ...      NaN                          6.0
#
#              aeacn3_1  aerelnst_c                        aerelnst aerelnst_nd  \
# 0    DOSE NOT CHANGED         3.0                           OTHER
# 1    DOSE NOT CHANGED         1.0      CONCOMITANT DRUG TREATMENT
# 2    DOSE NOT CHANGED         3.0                           OTHER
# 3                             3.0                           OTHER
# 4                             NaN
# ..                ...         ...                             ...         ...
# 723  DOSE NOT CHANGED         3.0                           OTHER
# 724  DOSE NOT CHANGED         3.0                           OTHER
# 725  DOSE NOT CHANGED         2.0  CONCOMITANT NON-DRUG TREATMENT
# 726                           NaN
# 727    NOT APPLICABLE         3.0                           OTHER
#
#                      aerelt aeout_c                       aeout
# 0    BONE MARROW ASPIRATION     3.0          RECOVERED/RESOLVED
# 1                               3.0          RECOVERED/RESOLVED
# 2    Due to primary disease     3.0          RECOVERED/RESOLVED
# 3                       AML     3.0          RECOVERED/RESOLVED
# 4                               3.0          RECOVERED/RESOLVED
# ..                      ...     ...                         ...
# 723                 UNKNOWN     3.0          RECOVERED/RESOLVED
# 724                     AML     3.0          RECOVERED/RESOLVED
# 725                             6.0                     UNKNOWN
# 726                             3.0          RECOVERED/RESOLVED
# 727                 unknown     2.0  NOT RECOVERED/NOT RESOLVED
#
# [728 rows x 88 columns]

# %%
ae_df=ae["aestdat_dts"]
ae_df.head(20)
# Out:
# 0      4/26/2018
# 1      6/25/2018
# 2       6/6/2018
# 3       9/4/2018
# 4       6/8/2018
# 5      6/17/2018
# 6      6/15/2018
# 7       7/1/2018
# 8       7/4/2018
# 9      6/30/2018
# 10     8/17/2018
# 11     8/27/2018
# 12     6/27/2018
# 13     7/17/2018
# 14      8/4/2018
# 15      8/8/2018
# 16     7/30/2018
# 17     8/16/2018
# 18    11/12/2018
# 19      9/3/2018
# Name: aestdat_dts, dtype: object

# %%
a=ae['aespid'].astype('str')
ae['aespid']=a.str.replace('.0','')

# %%
appended_data1 = []
for i in Sub_ID_cm['data']:
    d=requests.get(f'https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/{i}/list', verify=False)
    output4=json.loads(d.text)
    appended_data1.append(output4)
Task1_cm=pd.DataFrame(appended_data1)

# %%
cm_names=[]
for x in Task1_cm['data']:
    n = x[0]
    cm_names.append(n)

# %%
cm=pd.DataFrame(cm_names)
cm
# Out:
#        studyid  siteid    subjid  subjectid  visitid  visitidx visitnam  \
# 0    StudyHack    5173  51735001      76809    38942         1     AECM
# 1    StudyHack    5535  55355001     130301    38942         1     AECM
# 2    StudyHack    5162  51625001     132645    38942         1     AECM
# 3    StudyHack    5086  50865001     138700    38942         1     AECM
# 4    StudyHack    5178  51785002     166621    38942         1     AECM
# ..         ...     ...       ...        ...      ...       ...      ...
# 717  StudyHack    5523  55235005   55325218    38942         1     AECM
# 718  StudyHack    5172  51725006   55334564    38942         1     AECM
# 719  StudyHack    5099  50995004   55392353    38942         1     AECM
# 720  StudyHack    5176  51765008   55396342    38942         1     AECM
# 721  StudyHack    5184  51845002   55397989    38942         1     AECM
#
#     formname  formid  formidx  ...  cmstdat_dts     cmendat cmendat_dtr  \
# 0      CM201   38623       76  ...    7/14/2018    2-Sep-18    9/2/2018
# 1    CM201_3   32993        1  ...    7/23/2018   25-Jul-18
# 2    CM201_3   32993        1  ...    8/50/2018  51/51/2018
# 3    CM201_3   32993        1  ...   50/16/2018  50/16/2018
# 4      CM201   38623       94  ...    9/16/2018   21-Sep-18   9/21/2018
# ..       ...     ...      ...  ...          ...         ...         ...
# 717    CM201   38623        4  ...    8/29/2019    9-Sep-19    9/9/2019
# 718    CM201   38623        1  ...    9/26/2019   50/4/2019   50/4/2019
# 719  CM201_3   32993        1  ...   50/28/2019  51/29/2019
# 720    CM201   38623       76  ...   50/22/2019  50/23/2019  50/23/2019
# 721  CM201_3   32993        1  ...    9/26/2019   28-Sep-19
#
#      cmendat_dts cmongo cmongo_c cmongo_nd  \
# 0       9/2/2018     NO        N
# 1      7/25/2018     NO        N
# 2     51/51/2018     NO        N
# 3     50/16/2018     NO        N
# 4      9/21/2018     NO        N
# ..           ...    ...      ...       ...
# 717     9/9/2019     NO        N
# 718    50/4/2019     NO        N
# 719   51/29/2019     NO        N
# 720   50/23/2019     NO        N
# 721    9/28/2019     NO        N
#
#                                    compterm                   cmdecod   siteno
# 0                             ACETAMINOPHEN               PARACETAMOL    14931
# 1                          HYDROXYCARBAMIDE          HYDROXYCARBAMIDE    53053
# 2                                CYTARABINE                CYTARABINE    53343
# 3                              Cyclosporine               CICLOSPORIN   523266
# 4                                 ERTAPENEM                 ERTAPENEM   143192
# ..                                      ...                       ...      ...
# 717                        HYDROXYCARBAMIDE          HYDROXYCARBAMIDE   290816
# 718                RAMOSETRON HYDROCHLORIDE  RAMOSETRON HYDROCHLORIDE    53179
# 719                            JNJ-63709178      INVESTIGATIONAL DRUG   288220
# 720                    LEVOFLOXACIN HYDRATE              LEVOFLOXACIN    14889
# 721  IDARUBICIN HYDROCHLORIDE FOR INJECTION  IDARUBICIN HYDROCHLORIDE  3259974
#
# [722 rows x 49 columns]

# %%
ae.columns
# Out:
# Index(['studyid', 'siteid', 'subjid', 'subjectid', 'visitindex', 'visitnam',
#        'formname', 'formid', 'formidx', 'formindex', 'dov', 'aemeyn',
#        'aemeyn_c', 'aecat', 'aecat_c', 'aeterm', 'aemedrg', 'aeinpkg',
#        'aestdat', 'aestdat_dts', 'aestdat_nd', 'aestdme', 'aestdme_c',
#        'aeendat', 'aeendat_dts', 'aeendat_nd', 'aedis', 'aedis_c', 'aemerae',
#        'aemerae_c', 'aespid', 'aendgiv', 'aendgiv_c', 'aecmgiv', 'aecmgiv_c',
#        'aecmgiv_nd', 'aerefid', 'compterm', 'aellt', 'aedecod', 'aehlt',
#        'aehlgt', 'aesoc', 'aemedrg_c', 'aespid_1', 'aeyn', 'aeyn_c',
#        'aeongo_c', 'aeongo', 'aetoxgr_c', 'aetoxgr', 'aeser_c', 'aeser',
#        'aerme_c', 'aerme', 'aetrt1', 'aetrt3_c', 'aerel1_c', 'aerel1',
#        'aerel1_nd', 'aeacn1_c', 'aeacn1', 'aeacn1_1_c', 'aeacn1_1', 'aetrt2',
#        'aetrt2_nd', 'aetrt2_c', 'aerel2_c', 'aerel2', 'aerel2_nd', 'aeacn2_c',
#        'aeacn2', 'aeacn2_1_c', 'aeacn2_1', 'aetrt3', 'aetrt1_c', 'aerel3_c',
#        'aerel3', 'aeacn3_c', 'aeacn3', 'aeacn3_1_c', 'aeacn3_1', 'aerelnst_c',
#        'aerelnst', 'aerelnst_nd', 'aerelt', 'aeout_c', 'aeout'],
#       dtype='object')

# %%
cm.columns
# Out:
# Index(['studyid', 'siteid', 'subjid', 'subjectid', 'visitid', 'visitidx',
#        'visitnam', 'formname', 'formid', 'formidx', 'formindex', 'cmyn',
#        'cmyn_c', 'cmcat_c', 'cmcat_nd', 'cmscat', 'cmscat_c', 'cmpresp',
#        'cmpresp_c', 'cmpresp_nd', 'cmtrt', 'cmtrt_nd', 'cmrgm', 'cmrgm_nd',
#        'cmindc', 'cmaeno', 'cmaer', 'cmaer_c', 'cmdostot', 'cmdostot_nd',
#        'cmdosu', 'cmdosu_c', 'cmdosu_nd', 'cmroute', 'cmroute_c', 'cmprior',
#        'cmprior_c', 'cmstdat', 'cmstdat_dtr', 'cmstdat_dts', 'cmendat',
#        'cmendat_dtr', 'cmendat_dts', 'cmongo', 'cmongo_c', 'cmongo_nd',
#        'compterm', 'cmdecod', 'siteno'],
#       dtype='object')

# %%
v=set(ae['aespid'])
ae_t=list(v)
ae_t
con='|'.join(ae_t).replace('|nan','')
con
# Out:
# '|12|68|64|63|17|94|25|21|16|83|32|31|44|53|46|76|28|37|8|39|2|95|15|71|14|135|67|1|75|35|85|4|34|38|33|6|36|88|22|3|27|42|9|7|18|59|24|19|45|43|56|11|29|23|13|73|26|62|52|5'

# %%
ae['aespid'].dtype
# Out:
# dtype('O')

# %%
cm['cmaeno'].dtype
# Out:
# dtype('O')

# %%
ae["aestdat_dts"]=pd.to_datetime(ae["aestdat_dts"])
ae["aestdat_dts"].head(20)
# Out:
# 0    2018-04-26
# 1    2018-06-25
# 2    2018-06-06
# 3    2018-09-04
# 4    2018-06-08
# 5    2018-06-17
# 6    2018-06-15
# 7    2018-07-01
# 8    2018-07-04
# 9    2018-06-30
# 10   2018-08-17
# 11   2018-08-27
# 12   2018-06-27
# 13   2018-07-17
# 14   2018-08-04
# 15   2018-08-08
# 16   2018-07-30
# 17   2018-08-16
# 18   2018-11-12
# 19   2018-09-03
# Name: aestdat_dts, dtype: datetime64[ns]

# %%
cm["cmstdat_dts"]=pd.to_datetime(cm["cmstdat_dts"],errors='coerce')
a=cm["cmstdat_dts"]
cm_dt=a.dropna()
cm_dt.head(20)
# Out:
# 0    2018-07-14
# 1    2018-07-23
# 4    2018-09-16
# 5    2018-08-07
# 6    2018-07-03
# 9    2018-08-03
# 10   2018-09-07
# 12   2018-05-01
# 14   2018-08-22
# 15   2018-08-21
# 17   2018-08-27
# 18   2018-09-01
# 20   2018-09-17
# 21   2019-04-19
# 25   2018-09-13
# 27   2019-05-24
# 30   2018-07-18
# 31   2018-06-05
# 32   2018-09-03
# 33   2018-06-08
# Name: cmstdat_dts, dtype: datetime64[ns]

# %%
 cm['cmaeno'].dropna()
# Out:
# 0      19
# 1
# 2
# 3
# 4      16
#        ..
# 717
# 718
# 719
# 720    21
# 721
# Name: cmaeno, Length: 722, dtype: object

# %%
col1 = cm['cmaeno']

# %%
col2 = ae['aespid']

# %%
for i in col1:
    for j in col2:
        if i > 0:
            print(i,j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26876/766913607.py in <module>
#       1 for i in col1:
#       2     for j in col2:
# ----> 3         if i > 0:
#       4             print(i,j)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
fi=pd.merge(ae,cm,on='subjid',how='outer')
fi
# Out:
#      studyid_x  siteid_x    subjid  subjectid_x  visitindex visitnam_x  \
# 0    StudyHack    5173.0  51735001      76809.0         1.0       AECM
# 1    StudyHack    5538.0  55385001     105792.0         1.0       AECM
# 2    StudyHack    5160.0  51605001     117691.0         1.0       AECM
# 3    StudyHack    5160.0  51605002     120205.0         1.0       AECM
# 4    StudyHack    5535.0  55355001     130301.0         1.0       AECM
# ..         ...       ...       ...          ...         ...        ...
# 732        NaN       NaN  51725001          NaN         NaN        NaN
# 733        NaN       NaN  51135005          NaN         NaN        NaN
# 734        NaN       NaN  50605005          NaN         NaN        NaN
# 735        NaN       NaN  50835002          NaN         NaN        NaN
# 736        NaN       NaN  50445053          NaN         NaN        NaN
#
#     formname_x  formid_x  formidx_x   formindex_x  ... cmstdat_dts  \
# 0        AE202   38768.0        4.0  5.550000e+14  ...  2018-07-14
# 1        AE202   38768.0       43.0  5.520000e+14  ...  2018-07-18
# 2        AE202   38768.0       16.0  5.510000e+14  ...  2018-06-05
# 3      AE202_2   35537.0        1.0  5.580000e+14  ...  2018-09-03
# 4        AE202   38768.0        1.0  5.550000e+14  ...  2018-07-23
# ..         ...       ...        ...           ...  ...         ...
# 732        NaN       NaN        NaN           NaN  ...         NaT
# 733        NaN       NaN        NaN           NaN  ...  2019-02-02
# 734        NaN       NaN        NaN           NaN  ...  2009-01-01
# 735        NaN       NaN        NaN           NaN  ...  2008-01-01
# 736        NaN       NaN        NaN           NaN  ...  2017-06-01
#
#         cmendat  cmendat_dtr cmendat_dts  cmongo cmongo_c cmongo_nd  \
# 0      2-Sep-18     9/2/2018    9/2/2018      NO        N
# 1     23-Jul-18                7/23/2018      NO        N
# 2     6/52/2018    6/52/2018   6/52/2018      NO        N
# 3      3-Sep-18     9/3/2018    9/3/2018      NO        N
# 4     25-Jul-18                7/25/2018      NO        N
# ..          ...          ...         ...     ...      ...       ...
# 732  52/18/2018   52/18/2018  52/18/2018      NO        N
# 733    8-Feb-19                 2/8/2019      NO        N
# 734                                          YES        Y
# 735   25-Jun-19    6/25/2019   6/25/2019      NO        N
# 736              2018/03/UNK     2018-03
#
#                      compterm_y                      cmdecod    siteno
# 0                 ACETAMINOPHEN                  PARACETAMOL   14931.0
# 1                  MITOXANTRONE                 MITOXANTRONE   53423.0
# 2             MEROPENEM HYDRATE                    MEROPENEM   53055.0
# 3    D-CHLORPHENIRAMINE MALEATE  DEXCHLORPHENIRAMINE MALEATE   53055.0
# 4              HYDROXYCARBAMIDE             HYDROXYCARBAMIDE   53053.0
# ..                          ...                          ...       ...
# 732            HYDROXYCARBAMIDE             HYDROXYCARBAMIDE   53179.0
# 733       CYTARABINE+IDARUBICIN        CYTARABINE;IDARUBICIN  290734.0
# 734         METOPROLOLI TARTRAS          METOPROLOL TARTRATE  289528.0
# 735                   CAPTOPRIL                    CAPTOPRIL  289334.0
# 736                 Azacitidine                  AZACITIDINE  289004.0
#
# [737 rows x 136 columns]

# %%
fi.columns
# Out:
# Index(['studyid_x', 'siteid_x', 'subjid', 'subjectid_x', 'visitindex',
#        'visitnam_x', 'formname_x', 'formid_x', 'formidx_x', 'formindex_x',
#        ...
#        'cmstdat_dts', 'cmendat', 'cmendat_dtr', 'cmendat_dts', 'cmongo',
#        'cmongo_c', 'cmongo_nd', 'compterm_y', 'cmdecod', 'siteno'],
#       dtype='object', length=136)

# %%
a=fi['aespid']
ae_pi=a.dropna()
ae_pi
# Out:
# 0       4
# 1      43
# 2      16
# 3       1
# 4       1
#        ..
# 725     2
# 726     1
# 727     9
# 728    11
# 729    12
# Name: aespid, Length: 730, dtype: object

# %%
b=fi['cmaeno']
cm_t=b.dropna(0)
cm_t
# Out:
# 0      19
# 1
# 2      53
# 3
# 4
#        ..
# 732
# 733
# 734
# 735
# 736
# Name: cmaeno, Length: 724, dtype: object

# %%
fin=fi[fi['aespid']==fi['cmaeno']].reset_index().drop(columns='index')
fin
# Out:
#     studyid_x  siteid_x    subjid  subjectid_x  visitindex visitnam_x  \
# 0   StudyHack    5052.0  50525008    1393002.0         1.0       AECM
# 1   StudyHack    5522.0  55225006    1525878.0         1.0       AECM
# 2   StudyHack    5079.0  50795050    1544413.0         1.0       AECM
# 3   StudyHack    5167.0  51675004    1797795.0         1.0       AECM
# 4   StudyHack    5538.0  55385051    1898906.0         1.0       AECM
# 5   StudyHack    5035.0  50355022    2187493.0         1.0       AECM
# 6   StudyHack    5033.0  50335001    2519940.0         1.0       AECM
# 7   StudyHack    5179.0  51795007    2559014.0         1.0       AECM
# 8   StudyHack    5060.0  50605002    3263209.0         1.0       AECM
# 9   StudyHack    5130.0  51305005    3537823.0         1.0       AECM
# 10  StudyHack    5179.0  51795051    3958754.0         1.0       AECM
# 11  StudyHack    5044.0  50445009    4123883.0         1.0       AECM
# 12  StudyHack    5060.0  50605006    4745381.0         1.0       AECM
# 13  StudyHack    5035.0  50355038    4928178.0         1.0       AECM
# 14  StudyHack    5062.0  50625006    5476054.0         1.0       AECM
# 15  StudyHack    5019.0  50195002    5920663.0         1.0       AECM
# 16  StudyHack    5163.0  51635050    6033167.0         1.0       AECM
# 17  StudyHack    5028.0  50285006    6068090.0         1.0       AECM
# 18  StudyHack    5060.0  50605050    6972006.0         1.0       AECM
# 19  StudyHack    5065.0  50655050    7242035.0         1.0       AECM
# 20  StudyHack    5061.0  50653005    8370657.0         1.0       AECM
# 21  StudyHack    5091.0  50953003    8966797.0         1.0       AECM
# 22  StudyHack    5048.0  50485002   10413893.0         1.0       AECM
# 23  StudyHack    5195.0  51955002   11372542.0         1.0       AECM
# 24  StudyHack    5078.0  50785020   13471171.0         1.0       AECM
# 25  StudyHack    5195.0  51955009   13591226.0         1.0       AECM
# 26  StudyHack    5079.0  50795032   13629484.0         1.0       AECM
# 27  StudyHack    5181.0  51853030   14221365.0         1.0       AECM
# 28  StudyHack    5181.0  51853036   14642001.0         1.0       AECM
# 29  StudyHack    5061.0  50653007   15292128.0         1.0       AECM
# 30  StudyHack    5195.0  51955014   16287031.0         1.0       AECM
#
#    formname_x  formid_x  formidx_x   formindex_x  ... cmstdat_dts     cmendat  \
# 0       AE202   38768.0        1.0  5.730000e+14  ...         NaT   1/53/2019
# 1       AE202   38768.0       10.0  6.160000e+14  ...  2019-05-01    5-May-19
# 2     AE202_2   35537.0       10.0  5.740000e+14  ...  2019-05-27   8/51/2019
# 3       AE202   38768.0        1.0  5.700000e+14  ...  2019-01-26   26-Jan-19
# 4       AE202   38768.0       40.0  5.840000e+14  ...  2019-01-09   1/50/2019
# 5     AE202_2   35537.0       10.0  5.990000e+14  ...  2017-04-01    7-Jan-19
# 6     AE202_2   35537.0        1.0  5.800000e+14  ...  2050-05-21
# 7       AE202   38768.0       80.0  6.040000e+14  ...  2019-02-09   14-Feb-19
# 8     AE202_2   35537.0       20.0  5.830000e+14  ...  2019-05-20    4-Jun-19
# 9     AE202_2   35537.0        1.0  5.760000e+14  ...  2019-04-02   4/51/2019
# 10      AE202   38768.0       10.0  5.800000e+14  ...         NaT   7/53/2019
# 11    AE202_2   35537.0        1.0  5.800000e+14  ...  2019-04-27    1-May-19
# 12    AE202_2   35537.0       10.0  5.840000e+14  ...  2019-05-07   17-May-19
# 13      AE202   38768.0        1.0  6.150000e+14  ...  2019-05-22   22-May-19
# 14    AE202_2   35537.0        1.0  5.970000e+14  ...  2019-05-20   25-May-19
# 15    AE202_2   35537.0        1.0  5.830000e+14  ...  2019-06-19   24-Jun-19
# 16    AE202_2   35537.0       30.0  6.160000e+14  ...  2019-06-18
# 17      AE202   38768.0        1.0  5.850000e+14  ...  2019-06-20   26-Jun-19
# 18    AE202_2   35537.0        1.0  5.870000e+14  ...  2019-07-20    6-Aug-19
# 19      AE202   38768.0       10.0  5.970000e+14  ...  2019-07-08   14-Jul-19
# 20    AE202_2   35537.0        1.0  5.870000e+14  ...  2019-08-07
# 21    AE202_2   35537.0        1.0  5.890000e+14  ...  2019-08-24    8-Sep-19
# 22    AE202_2   35537.0        1.0  5.950000e+14  ...  2019-08-30   30-Aug-19
# 23    AE202_2   35537.0       30.0  6.010000e+14  ...  2019-09-30   30-Sep-19
# 24      AE202   38768.0       10.0  5.960000e+14  ...         NaT  50/28/2019
# 25      AE202   38768.0        1.0  5.970000e+14  ...         NaT  51/50/2019
# 26      AE202   38768.0       30.0  6.160000e+14  ...         NaT  50/29/2019
# 27      AE202   38768.0       10.0  5.970000e+14  ...         NaT  51/21/2019
# 28      AE202   38768.0        1.0  6.000000e+14  ...         NaT  51/25/2019
# 29      AE202   38768.0        1.0  5.980000e+14  ...         NaT  51/30/2019
# 30    AE202_2   35537.0       20.0  6.070000e+14  ...         NaT
#
#    cmendat_dtr cmendat_dts  cmongo cmongo_c cmongo_nd  \
# 0    1/53/2019   1/53/2019      NO        N
# 1                 5/5/2019      NO        N
# 2                8/51/2019      NO        N
# 3    1/26/2019   1/26/2019      NO        N
# 4    1/50/2019   1/50/2019      NO        N
# 5     1/7/2019    1/7/2019
# 6                              YES        Y
# 7    2/14/2019   2/14/2019
# 8                 6/4/2019      NO        N
# 9    4/51/2019   4/51/2019      NO        N
# 10               7/53/2019      NO        N
# 11    5/1/2019    5/1/2019      NO        N
# 12   5/17/2019   5/17/2019      NO        N
# 13   5/22/2019   5/22/2019      NO        N
# 14   5/25/2019   5/25/2019      NO        N
# 15   6/24/2019   6/24/2019      NO        N
# 16                             YES        Y
# 17   6/26/2019   6/26/2019      NO        N
# 18    8/6/2019    8/6/2019      NO        N
# 19   7/14/2019   7/14/2019      NO        N
# 20                             YES        Y
# 21    9/8/2019    9/8/2019      NO        N
# 22   8/30/2019   8/30/2019      NO        N
# 23   9/30/2019   9/30/2019      NO        N
# 24  50/28/2019  50/28/2019      NO        N
# 25  51/50/2019  51/50/2019      NO        N
# 26  50/29/2019  50/29/2019      NO        N
# 27  51/21/2019  51/21/2019      NO        N
# 28  51/25/2019  51/25/2019      NO        N
# 29  51/30/2019  51/30/2019      NO        N
# 30                             YES        Y
#
#                                          compterm_y  \
# 0                                             ZOSYN
# 1                                          BUSULFEX
# 2                                           LITALIR
# 3                                        MICAFUNGIN
# 4                                  HYDROXYCARBAMIDE
# 5                                            HYDREA
# 6   ZOMARIST [METFORMIN HYDROCHLORIDE;VILDAGLIPTIN]
# 7                                       HYDROXYUREA
# 8                                   HYDROXYCARBAMID
# 9                                  HYDROXYCARBAMIDE
# 10                                      FLUDARABINE
# 11               SETRON (ONDANSETRON HYDROCHLORIDE)
# 12                                  CIPROFLOXACINUM
# 13                                       POLARAMINE
# 14                                     TRIMETHOPRIM
# 15                                    METOCLOPRAMID
# 16                             SENNOSIDE AB CALCIUM
# 17                                    PIPERACILLINE
# 18                                       CEFUROXIME
# 19                               SODIUM BICARBONATE
# 20                                   DEXKETOPROFENE
# 21                                      VORICONAZOL
# 22                                    CORTISOLU INJ
# 23                   CHLORPHENAMINE MALEATE TABLETS
# 24                        1/2 0,9% NATRII CHLORIDUM
# 25         DEXAMETHASONE SODIUM PHOSPHATE INJECTION
# 26                                          LITALIR
# 27                            WATER-SOLUBLE VITAMIN
# 28        PIPERACILLIN SODIUM AND TAZOBACTAM SODIUM
# 29                                       AMLODIPINE
# 30                                      Azacitidine
#
#                                               cmdecod     siteno
# 0               PIPERACILLIN SODIUM;TAZOBACTAM SODIUM   288550.0
# 1                                            BUSULFAN    78379.0
# 2                                    HYDROXYCARBAMIDE   538594.0
# 3                                          MICAFUNGIN   292218.0
# 4                                    HYDROXYCARBAMIDE    53423.0
# 5                                    HYDROXYCARBAMIDE   288178.0
# 6                METFORMIN HYDROCHLORIDE;VILDAGLIPTIN   289374.0
# 7                                    HYDROXYCARBAMIDE   295304.0
# 8                                    HYDROXYCARBAMIDE   289528.0
# 9                                    HYDROXYCARBAMIDE   292094.0
# 10                                        FLUDARABINE   295304.0
# 11                          ONDANSETRON HYDROCHLORIDE   289004.0
# 12                                      CIPROFLOXACIN   289528.0
# 13                        DEXCHLORPHENIRAMINE MALEATE   288178.0
# 14                                       TRIMETHOPRIM   290444.0
# 15                                     METOCLOPRAMIDE   233528.0
# 16                              SENNOSIDE A+B CALCIUM    53301.0
# 17                                PIPERACILLIN SODIUM   288674.0
# 18                                         CEFUROXIME   289528.0
# 19                                 SODIUM BICARBONATE   142998.0
# 20                                      DEXKETOPROFEN   288262.0
# 21                                       VORICONAZOLE   291928.0
# 22                    HYDROCORTISONE SODIUM SUCCINATE   142903.0
# 23                             CHLORPHENAMINE MALEATE  3258684.0
# 24                                    SODIUM CHLORIDE   538400.0
# 25                     DEXAMETHASONE SODIUM PHOSPHATE  3258684.0
# 26                                   HYDROXYCARBAMIDE   538594.0
# 27  BIOTIN;CYANOCOBALAMIN;FOLIC ACID;GLYCINE;NICOT...  3259792.0
# 28              PIPERACILLIN SODIUM;TAZOBACTAM SODIUM  3259792.0
# 29                                         AMLODIPINE   288262.0
# 30                                        AZACITIDINE  3258684.0
#
# [31 rows x 136 columns]

# %%
type_2=fin[fin['aestdat_dts']<fin['cmstdat_dts']]

# %%
type_2
# Out:
#     studyid_x  siteid_x    subjid  subjectid_x  visitindex visitnam_x  \
# 1   StudyHack    5522.0  55225006    1525878.0         1.0       AECM
# 2   StudyHack    5079.0  50795050    1544413.0         1.0       AECM
# 6   StudyHack    5033.0  50335001    2519940.0         1.0       AECM
# 8   StudyHack    5060.0  50605002    3263209.0         1.0       AECM
# 9   StudyHack    5130.0  51305005    3537823.0         1.0       AECM
# 23  StudyHack    5195.0  51955002   11372542.0         1.0       AECM
#
#    formname_x  formid_x  formidx_x   formindex_x  ... cmstdat_dts    cmendat  \
# 1       AE202   38768.0       10.0  6.160000e+14  ...  2019-05-01   5-May-19
# 2     AE202_2   35537.0       10.0  5.740000e+14  ...  2019-05-27  8/51/2019
# 6     AE202_2   35537.0        1.0  5.800000e+14  ...  2050-05-21
# 8     AE202_2   35537.0       20.0  5.830000e+14  ...  2019-05-20   4-Jun-19
# 9     AE202_2   35537.0        1.0  5.760000e+14  ...  2019-04-02  4/51/2019
# 23    AE202_2   35537.0       30.0  6.010000e+14  ...  2019-09-30  30-Sep-19
#
#    cmendat_dtr cmendat_dts  cmongo cmongo_c cmongo_nd  \
# 1                 5/5/2019      NO        N
# 2                8/51/2019      NO        N
# 6                              YES        Y
# 8                 6/4/2019      NO        N
# 9    4/51/2019   4/51/2019      NO        N
# 23   9/30/2019   9/30/2019      NO        N
#
#                                          compterm_y  \
# 1                                          BUSULFEX
# 2                                           LITALIR
# 6   ZOMARIST [METFORMIN HYDROCHLORIDE;VILDAGLIPTIN]
# 8                                   HYDROXYCARBAMID
# 9                                  HYDROXYCARBAMIDE
# 23                   CHLORPHENAMINE MALEATE TABLETS
#
#                                  cmdecod     siteno
# 1                               BUSULFAN    78379.0
# 2                       HYDROXYCARBAMIDE   538594.0
# 6   METFORMIN HYDROCHLORIDE;VILDAGLIPTIN   289374.0
# 8                       HYDROXYCARBAMIDE   289528.0
# 9                       HYDROXYCARBAMIDE   292094.0
# 23                CHLORPHENAMINE MALEATE  3258684.0
#
# [6 rows x 136 columns]

# %%
#pd.merge(product,customer,on='Product_ID')
