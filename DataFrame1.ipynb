# %%
import pandas as pd

# %%
api=pd.read_csv("myfile.txt")

# %%
api.values
# Out:
# array([['awery', 'bostoncoach', 0.0, 'PG', 25.0, '6-2', 80, 'peri',
#         700000.0],
#        ['john', 'bostoncoach', 99.0, 'SF', 27.0, '7-1', 55, 'sairam',
#         780000.0],
#        ['joal', 'bostoncoach', 77.0, 'SG', 27.0, '8-3', 77, 'PSP', nan],
#        ['mack', 'bostoncoach', 66.0, 'C', 44.0, '8-1', 70, '60000', nan],
#        ['tibor', 'bostoncoach', 89.0, 'C', 36.0, '7-3', 75,
#         'Madras Univarsity', 80000.0]], dtype=object)

# %%
api.head(n=1)
# Out:
#     name         teem  number position   age height  weight college    salary
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80    peri  700000.0

# %%
api.tail(n=1)
# Out:
#     name         teem  number position   age height  weight  \
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college   salary
# 4  Madras Univarsity  80000.0

# %%
api.shape
# Out:
# (5, 9)

# %%
api.dtypes
# Out:
# name         object
# teem         object
# number      float64
# position     object
# age         float64
# height       object
# weight        int64
# college      object
# salary      float64
# dtype: object

# %%
api.columns
# Out:
# Index(['name', 'teem', 'number', 'position', 'age', 'height', 'weight',
#        'college', 'salary'],
#       dtype='object')

# %%
api
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       NaN
# 3              60000       NaN
# 4  Madras Univarsity   80000.0

# %%
api.axes
# Out:
# [RangeIndex(start=0, stop=5, step=1),
#  Index(['name', 'teem', 'number', 'position', 'age', 'height', 'weight',
#         'college', 'salary'],
#        dtype='object')]

# %%
api.info
# Out:
# <bound method DataFrame.info of     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       NaN
# 3              60000       NaN
# 4  Madras Univarsity   80000.0  >

# %%
pwd
# Out:
# 'C:\\Users\\ELCOT'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is D69E-B34E
#
#  Directory of C:\Users\ELCOT
#
# 02-05-2022  15:02    <DIR>          .
# 02-05-2022  15:02    <DIR>          ..
# 17-04-2022  06:06             5,586 .bash_history
# 18-04-2022  13:29    <DIR>          .eclipse
# 23-03-2022  15:43               183 .gitconfig
# 02-05-2022  14:11    <DIR>          .ipynb_checkpoints
# 18-04-2022  11:40    <DIR>          .ipython
# 18-04-2022  18:06    <DIR>          .jupyter
# 23-03-2022  17:12                20 .lesshst
# 02-03-2022  09:39    <DIR>          .matplotlib
# 23-03-2022  12:44    <DIR>          .ssh
# 30-03-2022  17:18               913 .viminfo
# 27-01-2022  07:30    <DIR>          3D Objects
# 18-04-2022  11:36    <DIR>          anaconda3
# 19-02-2022  10:59            45,056 arasu.db
# 27-01-2022  07:30    <DIR>          Contacts
# 01-05-2022  12:38                 0 cur.txt
# 02-05-2022  15:02            12,469 DataFrame1.ipynb
# ...

# %%
con=pd.read_csv("newfile.txt",index_col="date")

# %%
con
con.head(3)
arr=pd.Series([1,2,3])

# %%
arr.sum()
# Out:
# 6

# %% [raw]
# con.sum()

# %%
con.sum(axis="index")
# Out:
# score         892.0
# Points         80.8
# strikrate    2064.0
# dtype: float64

# %%
con.sum(axis="columns")
# Out:
# date
# 1/01/2022     319.0
# 2/01/2022     209.8
# 3/01/2022     286.1
# 4/01/2022     261.0
# 5/01/2022     319.0
# 6/01/2022     209.8
# 7/01/2022     286.1
# 8/01/2022     261.0
# 9/01/2022     565.0
# 10/01/2022    320.0
# dtype: float64

# %%
import pandas as pd
api=pd.read_csv("myfile.txt")

# %%
api
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       NaN
# 3              60000       NaN
# 4  Madras Univarsity   80000.0

# %%
api.head(3)
# Out:
#     name         teem  number position   age height  weight college    salary
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80    peri  700000.0
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55  sairam  780000.0
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77     PSP       NaN

# %%
api.name
api.salary
api.number
output=None

# %%
api["name"]
# Out:
# 0    awery
# 1     john
# 2     joal
# 3     mack
# 4    tibor
# Name: name, dtype: object

# %%
api[["name","teem"]]
# Out:
#     name         teem
# 0  awery  bostoncoach
# 1   john  bostoncoach
# 2   joal  bostoncoach
# 3   mack  bostoncoach
# 4  tibor  bostoncoach

# %%
api[["teem","name"]]
# Out:
#           teem   name
# 0  bostoncoach  awery
# 1  bostoncoach   john
# 2  bostoncoach   joal
# 3  bostoncoach   mack
# 4  bostoncoach  tibor

# %%
select=["name","teem","salary"]
api[select]
# Out:
#     name         teem    salary
# 0  awery  bostoncoach  700000.0
# 1   john  bostoncoach  780000.0
# 2   joal  bostoncoach       NaN
# 3   mack  bostoncoach       NaN
# 4  tibor  bostoncoach   80000.0

# %%
api["sport"]="Football"

# %%
api.head()
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college    salary     sport
# 0               peri  700000.0  Football
# 1             sairam  780000.0  Football
# 2                PSP       NaN  Football
# 3              60000       NaN  Football
# 4  Madras Univarsity   80000.0  Football

# %%
api=pd.read_csv("myfile.txt")
api.head()
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       NaN
# 3              60000       NaN
# 4  Madras Univarsity   80000.0

# %%
api.insert(2,column="sport",value="Football")

# %%
api.head()
# Out:
#     name         teem     sport  number position   age height  weight  \
# 0  awery  bostoncoach  Football     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach  Football    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach  Football    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach  Football    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach  Football    89.0        C  36.0    7-3      75
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       NaN
# 3              60000       NaN
# 4  Madras Univarsity   80000.0

# %%
ope=pd.read_csv("myfile.txt")
ope
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       NaN
# 3              60000       NaN
# 4  Madras Univarsity   80000.0

# %%
ope["age"].add(5)
# Out:
# 0    30.0
# 1    32.0
# 2    32.0
# 3    49.0
# 4    41.0
# Name: age, dtype: float64

# %%
ope["salary"].sub(100000)
# Out:
# 0    600000.0
# 1    680000.0
# 2         NaN
# 3         NaN
# 4    -20000.0
# Name: salary, dtype: float64

# %%
ope["number"].mul(11.043)
# Out:
# 0       0.000
# 1    1093.257
# 2     850.311
# 3     728.838
# 4     982.827
# Name: number, dtype: float64

# %%
ope["weight in kilogram"]=ope["weight"].mul(50)

# %%
ope.head(3)
# Out:
#     name         teem  number position   age height  weight college    salary  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80    peri  700000.0
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55  sairam  780000.0
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77     PSP       NaN
#
#    weight in kilogram
# 0                4000
# 1                2750
# 2                3850

# %%
count=pd.read_csv("myfile.txt")
count
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       NaN
# 3              60000       NaN
# 4  Madras Univarsity   80000.0

# %%
count["teem"].value_counts()
# Out:
# bostoncoach    5
# Name: teem, dtype: int64

# %%
count["salary"].value_counts()
# Out:
# 700000.0    1
# 780000.0    1
# 80000.0     1
# Name: salary, dtype: int64

# %%
Drop=pd.read_csv("myfile.txt")
Drop.head()
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       NaN
# 3              60000       NaN
# 4  Madras Univarsity   80000.0

# %%
Drop.dropna(now="all",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21440/1642024145.py in <module>
# ----> 1 Drop.dropna(now="all",inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: dropna() got an unexpected keyword argument 'now'

# %%
Drop.dropna(subset=["salary"])
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 4  Madras Univarsity   80000.0

# %%
null=pd.read_csv("myfile.txt")
null["salary"].fillna(1000,inplace=True)
null.head()
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP    1000.0
# 3              60000    1000.0
# 4  Madras Univarsity   80000.0

# %%
null["salary"].fillna("no salary",inplace=True)

# %%
null.head()
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2      80
# 1   john  bostoncoach    99.0       SF  27.0    7-1      55
# 2   joal  bostoncoach    77.0       SG  27.0    8-3      77
# 3   mack  bostoncoach    66.0        C  44.0    8-1      70
# 4  tibor  bostoncoach    89.0        C  36.0    7-3      75
#
#              college     salary
# 0               peri   700000.0
# 1             sairam   780000.0
# 2                PSP  no salary
# 3              60000  no salary
# 4  Madras Univarsity    80000.0

# %%
asty=pd.read_csv("myfile.txt").dropna(how="all")
asty["salary"].fillna(0,inplace=True)
asty["college"].fillna("ARM",inplace=True)
asty.tail(1)
# Out:
#     name teem  number position  age height  weight college  salary
# 5  boonk  NaN     NaN      NaN  NaN    NaN     NaN     ARM     0.0

# %%
asty["weight"].nunique()
# Out:
# 5

# %%
asty["position"]=asty["position"].astype("category")
asty.head()
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2    80.0
# 1   john  bostoncoach    99.0       SF  27.0    7-1    55.0
# 2   joal  bostoncoach    77.0       SG  27.0    8-3    77.0
# 3   mack  bostoncoach    66.0        C  44.0    8-1    70.0
# 4  tibor  bostoncoach    89.0        C  36.0    7-3    75.0
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       0.0
# 3              60000       0.0
# 4  Madras Univarsity   80000.0

# %%
asty["teem"]=asty["teem"].astype("category")

# %%
asty.head()
# Out:
#     name         teem  number position   age height  weight  \
# 0  awery  bostoncoach     0.0       PG  25.0    6-2    80.0
# 1   john  bostoncoach    99.0       SF  27.0    7-1    55.0
# 2   joal  bostoncoach    77.0       SG  27.0    8-3    77.0
# 3   mack  bostoncoach    66.0        C  44.0    8-1    70.0
# 4  tibor  bostoncoach    89.0        C  36.0    7-3    75.0
#
#              college    salary
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       0.0
# 3              60000       0.0
# 4  Madras Univarsity   80000.0

# %%
nba=pd.read_csv("myfile.txt")
nba.head()
nba.sort_values("name",ascending=False)
nba.sort_values("age",ascending=False)
nba.sort_values("salary",ascending=True)
# Out:
#     name         teem  number position   age height  weight  \
# 4  tibor  bostoncoach    89.0        C  36.0    7-3    75.0
# 0  awery  bostoncoach     0.0       PG  25.0    6-2    80.0
# 1   john  bostoncoach    99.0       SF  27.0    7-1    55.0
# 2   joal  bostoncoach    77.0       SG  27.0    8-3    77.0
# 3   mack  bostoncoach    66.0        C  44.0    8-1    70.0
# 5  boonk          NaN     NaN      NaN   NaN    NaN     NaN
#
#              college    salary
# 4  Madras Univarsity   80000.0
# 0               peri  700000.0
# 1             sairam  780000.0
# 2                PSP       NaN
# 3              60000       NaN
# 5                NaN       NaN
