# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\ELCOT\Downloads\employees.csv")
df.head(3)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male  01/02/2000         12.00PM   87306     6.945
# 1     Thomas    Male  03/01/1996         11.17AM   61933     4.170
# 2      Maria  Female   4/23/1993         06.53AM  130590    11.958
#
#    Senior management Marketing
# 0               True       NaN
# 1               True   Finance
# 2              False   Finance

# %%
df["Start Date"]
# Out:
# 0    01/02/2000
# 1    03/01/1996
# 2     4/23/1993
# 3      3/4/2006
# 4     1/24/1995
# Name: Start Date, dtype: object

# %%
pd.to_datetime(df["Start Date"])
# Out:
# 0   2000-01-02
# 1   1996-03-01
# 2   1993-04-23
# 3   2006-03-04
# 4   1995-01-24
# Name: Start Date, dtype: datetime64[ns]

# %%
df["Last Login Time"]=pd.to_datetime(df["Last Login Time"], errors='coerce')
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02             NaT   87306    6.9450
# 1     Thomas    Male 1996-03-01             NaT   61933    4.1700
# 2      Maria  Female 1993-04-23             NaT  130590   11.9580
# 3      jerry    Male 2006-03-04             NaT  101004    1.3680
# 4      Larry    Male 1995-01-24             NaT   16655   16.5565
#
#    Senior management        Marketing
# 0               True              NaN
# 1               True          Finance
# 2              False          Finance
# 3               True  Client Services
# 4               True          Product

# %%
df["Start Date"]=pd.to_datetime(df["Start Date"])

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306     6.945
# 1     Thomas    Male 1996-03-01         11.17AM   61933     4.170
# 2      Maria  Female 1993-04-23         06.53AM  130590    11.958
#
#    Senior management Marketing
# 0               True       NaN
# 1               True   Finance
# 2              False   Finance

# %%
df["Gender"].astype("category")
# Out:
# 0      Male
# 1      Male
# 2    Female
# 3      Male
# 4      Male
# Name: Gender, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
df=pd.read_csv(r"C:\Users\ELCOT\Downloads\employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Senior management"]=df["Senior management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306     6.945
# 1     Thomas    Male 1996-03-01         11.17AM   61933     4.170
# 2      Maria  Female 1993-04-23         06.53AM  130590    11.958
#
#    Senior management Marketing
# 0               True       NaN
# 1               True   Finance
# 2              False   Finance

# %%
df["Gender"]=df["Gender"]
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306     6.945
# 1     Thomas    Male 1996-03-01         11.17AM   61933     4.170
# 2      Maria  Female 1993-04-23         06.53AM  130590    11.958
#
#    Senior management Marketing
# 0               True       NaN
# 1               True   Finance
# 2              False   Finance

# %%
df=pd.read_csv(r"C:\Users\ELCOT\Downloads\employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Senior management"]=df["Senior management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306    6.9450
# 1     Thomas    Male 1996-03-01         11.17AM   61933    4.1700
# 2      Maria  Female 1993-04-23         06.53AM  130590   11.9580
# 3      jerry    Male 2006-03-04          4.47PM  101004    1.3680
# 4      Larry    Male 1995-01-24          6.09AM   16655   16.5565
#
#    Senior management        Marketing
# 0               True              NaN
# 1               True          Finance
# 2              False          Finance
# 3               True  Client Services
# 4               True          Product

# %%
df[df["Gender"]=="Male"]
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas   Male 2000-01-02         12.00PM   87306    6.9450
# 1     Thomas   Male 1996-03-01         11.17AM   61933    4.1700
# 3      jerry   Male 2006-03-04          4.47PM  101004    1.3680
# 4      Larry   Male 1995-01-24          6.09AM   16655   16.5565
#
#    Senior management        Marketing
# 0               True              NaN
# 1               True          Finance
# 3               True  Client Services
# 4               True          Product

# %%
mask=df[df["Marketing"]=="Finance"]

# %%
df[mask]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37100/2581737305.py in <module>
# ----> 1 df[mask]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3443         # Do we have a (boolean) DataFrame?
#    3444         if isinstance(key, DataFrame):
# -> 3445             return self.where(key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#   10734         try_cast=lib.no_default,
#   10735     ):
# ...

# %%
df["Salary"]>100000
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Salary, dtype: bool

# %%
df[df["Bonous %"]>1.5]
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306    6.9450
# 1     Thomas    Male 1996-03-01         11.17AM   61933    4.1700
# 2      Maria  Female 1993-04-23         06.53AM  130590   11.9580
# 4      Larry    Male 1995-01-24          6.09AM   16655   16.5565
#
#    Senior management Marketing
# 0               True       NaN
# 1               True   Finance
# 2              False   Finance
# 4               True   Product

# %%
mask=df["Start Date"]<="02-01-2000"

# %%
df[mask]
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306    6.9450
# 1     Thomas    Male 1996-03-01         11.17AM   61933    4.1700
# 2      Maria  Female 1993-04-23         06.53AM  130590   11.9580
# 4      Larry    Male 1995-01-24          6.09AM   16655   16.5565
#
#    Senior management Marketing
# 0               True       NaN
# 1               True   Finance
# 2              False   Finance
# 4               True   Product

# %%
df=pd.read_csv(r"C:\Users\ELCOT\Downloads\employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Senior management"]=df["Senior management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306    6.9450
# 1     Thomas    Male 1996-03-01         11.17AM   61933    4.1700
# 2      Maria  Female 1993-04-23         06.53AM  130590   11.9580
# 3      jerry    Male 2006-03-04          4.47PM  101004    1.3680
# 4      Larry    Male 1995-01-24          6.09AM   16655   16.5565
#
#    Senior management        Marketing
# 0               True              NaN
# 1               True          Finance
# 2              False          Finance
# 3               True  Client Services
# 4               True          Product

# %%
mask1=df["Gender"]=="Male"
mask2=df["Marketing"]=="Product"

# %%
df[mask1 | mask2]
df[mask1 & mask2]
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonous %  \
# 4      Larry   Male 1995-01-24          6.09AM   16655   16.5565
#
#    Senior management Marketing
# 4               True   Product

# %%
df=pd.read_csv(r"C:\Users\ELCOT\Downloads\employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Senior management"]=df["Senior management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306     6.945
# 1     Thomas    Male 1996-03-01         11.17AM   61933     4.170
# 2      Maria  Female 1993-04-23         06.53AM  130590    11.958
#
#    Senior management Marketing
# 0               True       NaN
# 1               True   Finance
# 2              False   Finance

# %%
mask1=df["Marketing"]=="Product"
mask2=df["Marketing"]=="Finance"
mask3=df["Marketing"]=="Client Services"

# %%
df[mask1|mask2 | mask3]
mask=df["First Name"].isin(["Thomas","Larry" ,"jerry"])
df[mask]
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonous %  \
# 1     Thomas   Male 1996-03-01         11.17AM   61933    4.1700
# 3      jerry   Male 2006-03-04          4.47PM  101004    1.3680
# 4      Larry   Male 1995-01-24          6.09AM   16655   16.5565
#
#    Senior management        Marketing
# 1               True          Finance
# 3               True  Client Services
# 4               True          Product

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\ELCOT\Downloads\employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Senior management"]=df["Senior management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306    6.9450
# 1     Thomas    Male 1996-03-01         11.17AM   61933    4.1700
# 2      Maria  Female 1993-04-23         06.53AM  130590   11.9580
# 3      jerry    Male 2006-03-04          4.47PM  101004    1.3680
# 4      Larry    Male 1995-01-24          6.09AM   16655   16.5565
#
#    Senior management        Marketing
# 0               True              NaN
# 1               True          Finance
# 2              False          Finance
# 3               True  Client Services
# 4               True          Product

# %%
df[df["Last Login Time"].between("06.00AM","12.00PM")]
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306     6.945
# 1     Thomas    Male 1996-03-01         11.17AM   61933     4.170
# 2      Maria  Female 1993-04-23         06.53AM  130590    11.958
#
#    Senior management Marketing
# 0               True       NaN
# 1               True   Finance
# 2              False   Finance

# %%
df=pd.read_csv(r"C:\Users\ELCOT\Downloads\employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Senior management"]=df["Senior management"].astype("bool")
#df["Gender"]=df["Gender"].astype("category")
df.sort_values("First Name",inplace=True)
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306    6.9450
# 4      Larry    Male 1995-01-24          6.09AM   16655   16.5565
# 2      Maria  Female 1993-04-23         06.53AM  130590   11.9580
# 1     Thomas    Male 1996-03-01         11.17AM   61933    4.1700
# 3      jerry    Male 2006-03-04          4.47PM  101004    1.3680
#
#    Senior management        Marketing
# 0               True              NaN
# 4               True          Product
# 2              False          Finance
# 1               True          Finance
# 3               True  Client Services

# %%
df[df["Marketing"].duplicated(keep=False)]
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 2      Maria  Female 1993-04-23         06.53AM  130590    11.958
# 1     Thomas    Male 1996-03-01         11.17AM   61933     4.170
#
#    Senior management Marketing
# 2              False   Finance
# 1               True   Finance

# %%
df=pd.read_csv(r"C:\Users\ELCOT\Downloads\employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Senior management"]=df["Senior management"].astype("bool")
#df["Gender"]=df["Gender"].astype("category")
df.sort_values("First Name",inplace=True)
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306    6.9450
# 4      Larry    Male 1995-01-24          6.09AM   16655   16.5565
# 2      Maria  Female 1993-04-23         06.53AM  130590   11.9580
# 1     Thomas    Male 1996-03-01         11.17AM   61933    4.1700
# 3      jerry    Male 2006-03-04          4.47PM  101004    1.3680
#
#    Senior management        Marketing
# 0               True              NaN
# 4               True          Product
# 2              False          Finance
# 1               True          Finance
# 3               True  Client Services

# %%
len(df)
# Out:
# 5

# %%
len(df.drop_duplicates())
# Out:
# 5

# %%
df.drop_duplicates(subset=["First Name"])
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306    6.9450
# 4      Larry    Male 1995-01-24          6.09AM   16655   16.5565
# 2      Maria  Female 1993-04-23         06.53AM  130590   11.9580
# 1     Thomas    Male 1996-03-01         11.17AM   61933    4.1700
# 3      jerry    Male 2006-03-04          4.47PM  101004    1.3680
#
#    Senior management        Marketing
# 0               True              NaN
# 4               True          Product
# 2              False          Finance
# 1               True          Finance
# 3               True  Client Services

# %%
df=pd.read_csv(r"C:\Users\ELCOT\Downloads\employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Senior management"]=df["Senior management"].astype("bool")
#df["Gender"]=df["Gender"].astype("category")
df.sort_values("First Name",inplace=True)
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonous %  \
# 0    Douglas    Male 2000-01-02         12.00PM   87306    6.9450
# 4      Larry    Male 1995-01-24          6.09AM   16655   16.5565
# 2      Maria  Female 1993-04-23         06.53AM  130590   11.9580
# 1     Thomas    Male 1996-03-01         11.17AM   61933    4.1700
# 3      jerry    Male 2006-03-04          4.47PM  101004    1.3680
#
#    Senior management        Marketing
# 0               True              NaN
# 4               True          Product
# 2              False          Finance
# 1               True          Finance
# 3               True  Client Services

# %%
df["Marketing"].unique(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8952/2759070626.py in <module>
# ----> 1 df["Marketing"].unique(dropna=False)
#
# TypeError: unique() got an unexpected keyword argument 'dropna'
