# %%
import requests
import json
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import os

# %%
api1=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/list', verify=False)

# %%
api2=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/list', verify=False)

# %%
ae_str=json.loads(api1.text)

# %%
type(ae_str)
# Out:
# dict

# %%
cm_str1=json.loads(api2.text)

# %%
Sub_id_ae=pd.DataFrame(ae_str)
print(Sub_id_ae.head())
Sub_ID_cm=pd.DataFrame(cm_str1)
print(Sub_ID_cm.head())
# Out:
#     status    data                            request_id
# 0  success   76809  5d20a2fc-da99-4ca3-aabb-70d084815889
# 1  success  105792  5d20a2fc-da99-4ca3-aabb-70d084815889
# 2  success  117691  5d20a2fc-da99-4ca3-aabb-70d084815889
# 3  success  120205  5d20a2fc-da99-4ca3-aabb-70d084815889
# 4  success  130301  5d20a2fc-da99-4ca3-aabb-70d084815889
#     status    data                            request_id
# 0  success   76809  2a6fbacd-d8b9-472e-9220-76b0ea1a5830
# 1  success  130301  2a6fbacd-d8b9-472e-9220-76b0ea1a5830
# 2  success  132645  2a6fbacd-d8b9-472e-9220-76b0ea1a5830
# 3  success  138700  2a6fbacd-d8b9-472e-9220-76b0ea1a5830
# 4  success  166621  2a6fbacd-d8b9-472e-9220-76b0ea1a5830

# %%
Sub_id_ae['data']
# Out:
# 0         76809
# 1        105792
# 2        117691
# 3        120205
# 4        130301
#          ...
# 723    17954820
# 724    17956076
# 725    18042999
# 726    18282353
# 727    18291148
# Name: data, Length: 728, dtype: int64

# %%
c=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/105792/list', verify=False)
output3=json.loads(c.text)
Task1_ae=pd.DataFrame(output3)
Task1_ae
# Out:
#      status                                               data  \
# 0   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 1   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 2   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 3   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 4   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# ..      ...                                                ...
# 61  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 62  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 63  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 64  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 65  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
#
#                               request_id
# 0   1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 1   1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 2   1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 3   1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 4   1326f0f0-478e-411f-9cfa-e48d2cdd8644
# ..                                   ...
# 61  1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 62  1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 63  1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 64  1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 65  1326f0f0-478e-411f-9cfa-e48d2cdd8644
#
# [66 rows x 3 columns]

# %%
ae_data=[]
for i in Sub_id_ae['data']:
    c1=requests.get(f'https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/{i}/list', verify=False)
    dct1=json.loads(c1.text)
    ae_data.append(dct1)
count=pd.DataFrame(ae_data)
count
# Out:
#       status                                               data  \
# 0    success  [{'studyid': 'StudyHack', 'siteid': 5173, 'sub...
# 1    success  [{'studyid': 'StudyHack', 'siteid': 5538, 'sub...
# 2    success  [{'studyid': 'StudyHack', 'siteid': 5160, 'sub...
# 3    success  [{'studyid': 'StudyHack', 'siteid': 5160, 'sub...
# 4    success  [{'studyid': 'StudyHack', 'siteid': 5535, 'sub...
# ..       ...                                                ...
# 723  success  [{'studyid': 'StudyHack', 'siteid': 5045, 'sub...
# 724  success  [{'studyid': 'StudyHack', 'siteid': 5045, 'sub...
# 725  success  [{'studyid': 'StudyHack', 'siteid': 5303, 'sub...
# 726  success  [{'studyid': 'StudyHack', 'siteid': 5018, 'sub...
# 727  success  [{'studyid': 'StudyHack', 'siteid': 5018, 'sub...
#
#                                request_id
# 0    908bbc66-cbed-4cff-bee4-820562b88783
# 1    77306532-0777-4d30-a211-329163e17a13
# 2    968dd05c-83b6-4fec-a448-25d84966308c
# 3    19d717e1-1c3a-40d8-979f-506bd92d4262
# 4    cbb601e6-034d-43d6-ba74-22e8f7bbe277
# ..                                    ...
# 723  a5f1c7f7-446a-489f-8598-e0f5de0dd085
# 724  cad18642-a604-4311-bc33-04f7dd25c32d
# 725  c3fc9b3d-f9bf-4e76-b8ba-d224b635957a
# 726  954f5e4b-9e02-46a6-8c14-387dfebbed4e
# 727  77c492a6-c343-446c-bb12-d27cc06f8ce0
#
# [728 rows x 3 columns]

# %%
ae_table=pd.DataFrame(count['data'])
ae_table
# Out:
#       studyid  siteid    subjid  subjectid  visitindex visitnam formname  \
# 0   StudyHack    5018  50185008   18291148           1     AECM    AE202
# 1   StudyHack    5018  50185008   18291148           1     AECM    AE202
# 2   StudyHack    5018  50185008   18291148           1     AECM    AE202
# 3   StudyHack    5018  50185008   18291148           1     AECM    AE202
# 4   StudyHack    5018  50185008   18291148           1     AECM    AE202
# 5   StudyHack    5018  50185008   18291148           1     AECM    AE202
# 6   StudyHack    5018  50185008   18291148           1     AECM    AE202
# 7   StudyHack    5018  50185008   18291148           1     AECM    AE202
# 8   StudyHack    5018  50185008   18291148           1     AECM    AE202
# 9   StudyHack    5018  50185008   18291148           1     AECM    AE202
# 10  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 11  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 12  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 13  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 14  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 15  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 16  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 17  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 18  StudyHack    5018  50185008   18291148           1     AECM    AE202
#
#     formid  formidx     formindex  ... aeacn3_c            aeacn3 aeacn3_1_c  \
# 0    38768       12  6.030000e+14  ...      NaN                          6.0
# 1    38768       13  6.030000e+14  ...      6.0    NOT APPLICABLE        NaN
# 2    38768       17  6.030000e+14  ...      6.0    NOT APPLICABLE        NaN
# 3    38768       18  6.030000e+14  ...      NaN                          6.0
# 4    38768       19  6.040000e+14  ...      NaN                          6.0
# 5    38768        3  6.020000e+14  ...      6.0    NOT APPLICABLE        NaN
# 6    38768        4  6.020000e+14  ...      NaN                          2.0
# 7    38768        5  6.020000e+14  ...      2.0  DOSE NOT CHANGED        NaN
# 8    38768        6  6.020000e+14  ...      2.0  DOSE NOT CHANGED        NaN
# 9    38768        7  6.020000e+14  ...      NaN                          6.0
# 10   38768        8  6.020000e+14  ...      2.0  DOSE NOT CHANGED        NaN
# 11   38768        9  6.020000e+14  ...      6.0    NOT APPLICABLE        NaN
# 12   38768       10  6.030000e+14  ...      NaN                          2.0
# 13   38768       11  6.030000e+14  ...      6.0    NOT APPLICABLE        NaN
# 14   38768        1  6.020000e+14  ...      2.0  DOSE NOT CHANGED        NaN
# 15   38768        2  6.020000e+14  ...      2.0  DOSE NOT CHANGED        NaN
# 16   38768       20  6.180000e+14  ...      NaN                          6.0
# 17   38768       21  6.180000e+14  ...      6.0    NOT APPLICABLE        NaN
# 18   38768       22  6.180000e+14  ...      6.0    NOT APPLICABLE        NaN
#
#             aeacn3_1  aerelnst_c                        aerelnst aerelnst_nd  \
# 0     NOT APPLICABLE         3.0                           OTHER
# 1                            NaN
# 2                            NaN
# 3     NOT APPLICABLE         2.0  CONCOMITANT NON-DRUG TREATMENT
# 4     NOT APPLICABLE         3.0                           OTHER
# 5                            NaN
# 6   DOSE NOT CHANGED         3.0                           OTHER
# 7                            NaN
# 8                            NaN
# 9     NOT APPLICABLE         NaN
# 10                           NaN
# 11                           NaN
# 12  DOSE NOT CHANGED         3.0                           OTHER
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16    NOT APPLICABLE         NaN
# 17                           NaN
# 18                           NaN
#
#                      aerelt aeout_c                             aeout
# 0                   unknown       2        NOT RECOVERED/NOT RESOLVED
# 1                                 3                RECOVERED/RESOLVED
# 2                                 2        NOT RECOVERED/NOT RESOLVED
# 3                                 3                RECOVERED/RESOLVED
# 4                  LEUKEMIA       3                RECOVERED/RESOLVED
# 5                                 3                RECOVERED/RESOLVED
# 6   LEUKEMIA, PARAPROCTITIS       3                RECOVERED/RESOLVED
# 7                                 3                RECOVERED/RESOLVED
# 8                                 3                RECOVERED/RESOLVED
# 9                                 3                RECOVERED/RESOLVED
# 10                                3                RECOVERED/RESOLVED
# 11                                3                RECOVERED/RESOLVED
# 12                 LEUKEMIA       3                RECOVERED/RESOLVED
# 13                                4  RECOVERED/RESOLVED WITH SEQUELAE
# 14                                2        NOT RECOVERED/NOT RESOLVED
# 15                                4  RECOVERED/RESOLVED WITH SEQUELAE
# 16                                2        NOT RECOVERED/NOT RESOLVED
# 17                                3                RECOVERED/RESOLVED
# 18                                3                RECOVERED/RESOLVED
#
# [19 rows x 88 columns]

# %%
cm_data=[]
for i in Sub_ID_cm['data']:
    d=requests.get(f'https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/{i}/list', verify=False)
    result_2=json.loads(d.text)
    cm_data.append(result_2)
cm_table=pd.DataFrame(cm_data)
cm_table
# Out:
#       status                                               data  \
# 0    success  [{'studyid': 'StudyHack', 'siteid': 5173, 'sub...
# 1    success  [{'studyid': 'StudyHack', 'siteid': 5535, 'sub...
# 2    success  [{'studyid': 'StudyHack', 'siteid': 5162, 'sub...
# 3    success  [{'studyid': 'StudyHack', 'siteid': 5086, 'sub...
# 4    success  [{'studyid': 'StudyHack', 'siteid': 5178, 'sub...
# ..       ...                                                ...
# 717  success  [{'studyid': 'StudyHack', 'siteid': 5523, 'sub...
# 718  success  [{'studyid': 'StudyHack', 'siteid': 5172, 'sub...
# 719  success  [{'studyid': 'StudyHack', 'siteid': 5099, 'sub...
# 720  success  [{'studyid': 'StudyHack', 'siteid': 5176, 'sub...
# 721  success  [{'studyid': 'StudyHack', 'siteid': 5184, 'sub...
#
#                                request_id
# 0    551476aa-a942-4e6e-b8cf-feb10dd48402
# 1    aa8a8d85-381a-434c-8f51-6a52cedcbaa0
# 2    eb43c2c4-c92e-4172-aaeb-c2897a5520bd
# 3    0d896d77-34ef-4ec1-91d1-4e2de83eadc5
# 4    c80094aa-095b-4ae4-92d1-6692809e2b31
# ..                                    ...
# 717  2b72a92b-478a-43f9-85d9-fa8b8da6be79
# 718  9d906fbe-6275-4afd-a6ba-417b3a0f3998
# 719  4ef58d72-8d8f-41bc-8b98-d11ab0544ba6
# 720  c6601f29-ae6a-402e-b4b6-8606f45361fe
# 721  29cd43b4-b2e0-4b40-b519-bc342f5fdc6f
#
# [722 rows x 3 columns]

# %%
cm_list=list(cm_table['data'])
cm_list

# %%
def type1_check(ae_table, cm_table):
    first_list = []
    for cm_row in cm_table:
        for ae_row in ae_table:
            if cm_table in ae_table:
                
                payload = {}
                
                #payload['formname'] = cm_row['formidx']
                #payload['formid'] = "Fetch formid from cmrow"
                #payload['formidx'] = "Fetch formidx from cmrow"
                #payload['type'] = 'TYPE1'
                #payload['subjectid'] = "Fetch subjid from cmrow"
                first_list.append(payload)
                #first_list.to_csv('ae,cm_info_new.csv', sep = '\t')

    return first_list

# %%
a=pd.DataFrame(type1_check(ae_table,cm_table))
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23188/3314598149.py in <module>
# ----> 1 a=pd.DataFrame(type1_check(ae_table,cm_table))
#       2 a
#
# ~\AppData\Local\Temp/ipykernel_23188/1960326201.py in type1_check(ae_table, cm_table)
#       3     for cm_row in cm_table:
#       4         for ae_row in ae_table:
# ----> 5             if cm_table in ae_table:
#       6
#       7                 payload = {}
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __contains__(self, key)
#    1931     def __contains__(self, key) -> bool_t:
#    1932         """True if the key is in the info axis"""
# -> 1933         return key in self._info_axis
#    1934
#    1935     @property
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __contains__(self, key)
#    4570         False
#    4571         """
# -> 4572         hash(key)
#    4573         try:
#    4574             return key in self._engine
#
# TypeError: unhashable type: 'DataFrame'
