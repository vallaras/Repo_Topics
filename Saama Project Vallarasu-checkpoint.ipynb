# %%
import requests
import json
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import os

# %%
api1=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/list', verify=False)

# %%
api2=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/list', verify=False)

# %%
ae_str=json.loads(api1.text)

# %%
type(ae_str)
# Out:
# dict

# %%
cm_str1=json.loads(api2.text)

# %%
Sub_id_ae=pd.DataFrame(ae_str)
print(Sub_id_ae.head())
Sub_ID_cm=pd.DataFrame(cm_str1)
print(Sub_ID_cm.head())
# Out:
#     status    data                            request_id
# 0  success   76809  5d20a2fc-da99-4ca3-aabb-70d084815889
# 1  success  105792  5d20a2fc-da99-4ca3-aabb-70d084815889
# 2  success  117691  5d20a2fc-da99-4ca3-aabb-70d084815889
# 3  success  120205  5d20a2fc-da99-4ca3-aabb-70d084815889
# 4  success  130301  5d20a2fc-da99-4ca3-aabb-70d084815889
#     status    data                            request_id
# 0  success   76809  2a6fbacd-d8b9-472e-9220-76b0ea1a5830
# 1  success  130301  2a6fbacd-d8b9-472e-9220-76b0ea1a5830
# 2  success  132645  2a6fbacd-d8b9-472e-9220-76b0ea1a5830
# 3  success  138700  2a6fbacd-d8b9-472e-9220-76b0ea1a5830
# 4  success  166621  2a6fbacd-d8b9-472e-9220-76b0ea1a5830

# %%
Sub_id_ae['data']
# Out:
# 0         76809
# 1        105792
# 2        117691
# 3        120205
# 4        130301
#          ...
# 723    17954820
# 724    17956076
# 725    18042999
# 726    18282353
# 727    18291148
# Name: data, Length: 728, dtype: int64

# %%
c=requests.get('https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/105792/list', verify=False)
output3=json.loads(c.text)
Task1_ae=pd.DataFrame(output3)
Task1_ae
# Out:
#      status                                               data  \
# 0   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 1   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 2   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 3   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 4   success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# ..      ...                                                ...
# 61  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 62  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 63  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 64  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
# 65  success  {'studyid': 'StudyHack', 'siteid': 5538, 'subj...
#
#                               request_id
# 0   1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 1   1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 2   1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 3   1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 4   1326f0f0-478e-411f-9cfa-e48d2cdd8644
# ..                                   ...
# 61  1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 62  1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 63  1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 64  1326f0f0-478e-411f-9cfa-e48d2cdd8644
# 65  1326f0f0-478e-411f-9cfa-e48d2cdd8644
#
# [66 rows x 3 columns]

# %%
for i in Sub_id_ae['data']:
    c1=requests.get(f'https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/ae/subject/{i}/list', verify=False)
    dct1=json.loads(c1.text)
    count_ae=pd.DataFrame(dct1)

# %%
ae_table=pd.DataFrame(ls_data)
ae_table
# Out:
#          studyid  siteid    subjid  subjectid  visitindex visitnam formname  \
# 0      StudyHack    5173  51735001      76809           1     AECM    AE202
# 1      StudyHack    5173  51735001      76809           1     AECM    AE202
# 2      StudyHack    5173  51735001      76809           1     AECM    AE202
# 3      StudyHack    5173  51735001      76809           1     AECM    AE202
# 4      StudyHack    5173  51735001      76809           1     AECM    AE202
# ...          ...     ...       ...        ...         ...      ...      ...
# 20055  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20056  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20057  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20058  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20059  StudyHack    5018  50185008   18291148           1     AECM    AE202
#
#        formid  formidx     formindex  ... aeacn3_c            aeacn3  \
# 0       38768        4  5.550000e+14  ...      NaN
# 1       38768        6  5.550000e+14  ...      2.0  DOSE NOT CHANGED
# 2       38768        7  5.550000e+14  ...      2.0  DOSE NOT CHANGED
# 3       38768        9  5.550000e+14  ...      NaN
# 4       38768       10  5.550000e+14  ...      NaN
# ...       ...      ...           ...  ...      ...               ...
# 20055   38768        1  6.020000e+14  ...      2.0  DOSE NOT CHANGED
# 20056   38768        2  6.020000e+14  ...      2.0  DOSE NOT CHANGED
# 20057   38768       20  6.180000e+14  ...      NaN
# 20058   38768       21  6.180000e+14  ...      6.0    NOT APPLICABLE
# 20059   38768       22  6.180000e+14  ...      6.0    NOT APPLICABLE
#
#       aeacn3_1_c          aeacn3_1  aerelnst_c                    aerelnst  \
# 0            2.0  DOSE NOT CHANGED         3.0                       OTHER
# 1            NaN                           NaN
# 2            NaN                           NaN
# 3            2.0  DOSE NOT CHANGED         1.0  CONCOMITANT DRUG TREATMENT
# 4            2.0  DOSE NOT CHANGED         3.0                       OTHER
# ...          ...               ...         ...                         ...
# 20055        NaN                           NaN
# 20056        NaN                           NaN
# 20057        6.0    NOT APPLICABLE         NaN
# 20058        NaN                           NaN
# 20059        NaN                           NaN
#
#       aerelnst_nd                  aerelt aeout_c  \
# 0                  BONE MARROW ASPIRATION     3.0
# 1                                             3.0
# 2                                             3.0
# 3                                             3.0
# 4                           after bandage     3.0
# ...           ...                     ...     ...
# 20055                                         2.0
# 20056                                         4.0
# 20057                                         2.0
# 20058                                         3.0
# 20059                                         3.0
#
#                                   aeout
# 0                    RECOVERED/RESOLVED
# 1                    RECOVERED/RESOLVED
# 2                    RECOVERED/RESOLVED
# 3                    RECOVERED/RESOLVED
# 4                    RECOVERED/RESOLVED
# ...                                 ...
# 20055        NOT RECOVERED/NOT RESOLVED
# 20056  RECOVERED/RESOLVED WITH SEQUELAE
# 20057        NOT RECOVERED/NOT RESOLVED
# 20058                RECOVERED/RESOLVED
# 20059                RECOVERED/RESOLVED
#
# [20060 rows x 88 columns]

# %%
ae_table
# Out:
#          studyid  siteid    subjid  subjectid  visitindex visitnam formname  \
# 0      StudyHack    5173  51735001      76809           1     AECM    AE202
# 1      StudyHack    5173  51735001      76809           1     AECM    AE202
# 2      StudyHack    5173  51735001      76809           1     AECM    AE202
# 3      StudyHack    5173  51735001      76809           1     AECM    AE202
# 4      StudyHack    5173  51735001      76809           1     AECM    AE202
# ...          ...     ...       ...        ...         ...      ...      ...
# 20055  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20056  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20057  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20058  StudyHack    5018  50185008   18291148           1     AECM    AE202
# 20059  StudyHack    5018  50185008   18291148           1     AECM    AE202
#
#        formid  formidx     formindex  ... aeacn3_c            aeacn3  \
# 0       38768        4  5.550000e+14  ...      NaN
# 1       38768        6  5.550000e+14  ...      2.0  DOSE NOT CHANGED
# 2       38768        7  5.550000e+14  ...      2.0  DOSE NOT CHANGED
# 3       38768        9  5.550000e+14  ...      NaN
# 4       38768       10  5.550000e+14  ...      NaN
# ...       ...      ...           ...  ...      ...               ...
# 20055   38768        1  6.020000e+14  ...      2.0  DOSE NOT CHANGED
# 20056   38768        2  6.020000e+14  ...      2.0  DOSE NOT CHANGED
# 20057   38768       20  6.180000e+14  ...      NaN
# 20058   38768       21  6.180000e+14  ...      6.0    NOT APPLICABLE
# 20059   38768       22  6.180000e+14  ...      6.0    NOT APPLICABLE
#
#       aeacn3_1_c          aeacn3_1  aerelnst_c                    aerelnst  \
# 0            2.0  DOSE NOT CHANGED         3.0                       OTHER
# 1            NaN                           NaN
# 2            NaN                           NaN
# 3            2.0  DOSE NOT CHANGED         1.0  CONCOMITANT DRUG TREATMENT
# 4            2.0  DOSE NOT CHANGED         3.0                       OTHER
# ...          ...               ...         ...                         ...
# 20055        NaN                           NaN
# 20056        NaN                           NaN
# 20057        6.0    NOT APPLICABLE         NaN
# 20058        NaN                           NaN
# 20059        NaN                           NaN
#
#       aerelnst_nd                  aerelt aeout_c  \
# 0                  BONE MARROW ASPIRATION     3.0
# 1                                             3.0
# 2                                             3.0
# 3                                             3.0
# 4                           after bandage     3.0
# ...           ...                     ...     ...
# 20055                                         2.0
# 20056                                         4.0
# 20057                                         2.0
# 20058                                         3.0
# 20059                                         3.0
#
#                                   aeout
# 0                    RECOVERED/RESOLVED
# 1                    RECOVERED/RESOLVED
# 2                    RECOVERED/RESOLVED
# 3                    RECOVERED/RESOLVED
# 4                    RECOVERED/RESOLVED
# ...                                 ...
# 20055        NOT RECOVERED/NOT RESOLVED
# 20056  RECOVERED/RESOLVED WITH SEQUELAE
# 20057        NOT RECOVERED/NOT RESOLVED
# 20058                RECOVERED/RESOLVED
# 20059                RECOVERED/RESOLVED
#
# [20060 rows x 88 columns]

# %%
cm_data2 = []
for i in Sub_ID_cm['data']:
    d=requests.get(f'https://pharmanlp-177020.uc.r.appspot.com/api/1/StudyHack/cm/subject/{i}/list', verify=False)
    result_2=json.loads(d.text)
    data_cm=pd.DataFrame(result_2)
    for j in data_cm['data']:
         cm_data2.append(j)

# %%
cm_data2
# Out:
# [{'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 76,
#   'formindex': 556000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'ACETAMINOPHEN',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '19',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 500,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '14-Jul-18',
#   'cmstdat_dtr': '7/14/2018',
#   'cmstdat_dts': '7/14/2018',
#   'cmendat': '2-Sep-18',
#   'cmendat_dtr': '9/2/2018',
#   'cmendat_dts': '9/2/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'ACETAMINOPHEN',
#   'cmdecod': 'PARACETAMOL',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 77,
#   'formindex': 556000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'AZULENE GLUTAMINE COMBINATION FINE GRANULES',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 1,
#   'cmdostot_nd': '',
#   'cmdosu': 'g',
#   'cmdosu_c': 45,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '8/51/2018',
#   'cmstdat_dtr': '8/51/2018',
#   'cmstdat_dts': '8/51/2018',
#   'cmendat': '28-Sep-18',
#   'cmendat_dtr': '9/28/2018',
#   'cmendat_dts': '9/28/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'AZULENE GLUTAMINE COMBINATION FINE GRANULES',
#   'cmdecod': 'AZULENE;LEVOGLUTAMIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 78,
#   'formindex': 556000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'PENTAZOCINE HYDROCHLORIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '19',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 25,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '8-Aug-18',
#   'cmstdat_dtr': '8/8/2018',
#   'cmstdat_dts': '8/8/2018',
#   'cmendat': '8/51/2018',
#   'cmendat_dtr': '8/51/2018',
#   'cmendat_dts': '8/51/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'PENTAZOCINE HYDROCHLORIDE',
#   'cmdecod': 'PENTAZOCINE HYDROCHLORIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 79,
#   'formindex': 556000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'BAKTAR',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '16-Jul-18',
#   'cmstdat_dtr': '7/16/2018',
#   'cmstdat_dts': '7/16/2018',
#   'cmendat': '17-Aug-18',
#   'cmendat_dtr': '8/17/2018',
#   'cmendat_dts': '8/17/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'BAKTAR',
#   'cmdecod': 'SULFAMETHOXAZOLE;TRIMETHOPRIM',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 80,
#   'formindex': 556000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '48',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 1800,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '8-Aug-18',
#   'cmstdat_dtr': '8/8/2018',
#   'cmstdat_dts': '8/8/2018',
#   'cmendat': '13-Aug-18',
#   'cmendat_dtr': '8/13/2018',
#   'cmendat_dts': '8/13/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 81,
#   'formindex': 562000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'MAGNESIUM OXIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 660,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '7/51/2018',
#   'cmstdat_dtr': '7/51/2018',
#   'cmstdat_dts': '7/51/2018',
#   'cmendat': '27-Jul-18',
#   'cmendat_dtr': '7/27/2018',
#   'cmendat_dts': '7/27/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'MAGNESIUM OXIDE',
#   'cmdecod': 'MAGNESIUM OXIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 84,
#   'formindex': 576000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'METOCLOPRAMIDE HYDROCHLORIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '21',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 5,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '8/51/2018',
#   'cmstdat_dtr': '8/51/2018',
#   'cmstdat_dts': '8/51/2018',
#   'cmendat': '8/51/2018',
#   'cmendat_dtr': '8/51/2018',
#   'cmendat_dts': '8/51/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'METOCLOPRAMIDE HYDROCHLORIDE',
#   'cmdecod': 'METOCLOPRAMIDE HYDROCHLORIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 85,
#   'formindex': 576000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'TRAMADOL HYDROCHLORIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '19',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 25,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '9/50/2018',
#   'cmstdat_dtr': '9/50/2018',
#   'cmstdat_dts': '9/50/2018',
#   'cmendat': '51/30/2018',
#   'cmendat_dtr': '51/30/2018',
#   'cmendat_dts': '51/30/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'TRAMADOL HYDROCHLORIDE',
#   'cmdecod': 'TRAMADOL HYDROCHLORIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 86,
#   'formindex': 576000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'ITRACONAZOLE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 500,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '50/5/2018',
#   'cmstdat_dtr': '50/5/2018',
#   'cmstdat_dts': '50/5/2018',
#   'cmendat': '51/1/2018',
#   'cmendat_dtr': '51/1/2018',
#   'cmendat_dts': '51/1/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'ITRACONAZOLE',
#   'cmdecod': 'ITRACONAZOLE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 87,
#   'formindex': 576000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'MAGNESIUM OXIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 660,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '8/50/2018',
#   'cmstdat_dtr': '8/50/2018',
#   'cmstdat_dts': '8/50/2018',
#   'cmendat': '14-Sep-18',
#   'cmendat_dtr': '9/14/2018',
#   'cmendat_dts': '9/14/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'MAGNESIUM OXIDE',
#   'cmdecod': 'MAGNESIUM OXIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 88,
#   'formindex': 576000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'MAGNESIUM OXIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 330,
#   'cmdostot_nd': '',
#   'cmdosu': 'mL',
#   'cmdosu_c': 9,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '9/53/2018',
#   'cmstdat_dtr': '9/53/2018',
#   'cmstdat_dts': '9/53/2018',
#   'cmendat': '52/27/2018',
#   'cmendat_dtr': '52/27/2018',
#   'cmendat_dts': '52/27/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'MAGNESIUM OXIDE',
#   'cmdecod': 'MAGNESIUM OXIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 89,
#   'formindex': 576000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'METOCLOPRAMIDE HYDROCHLORIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '20',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 50,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '29-Aug-18',
#   'cmstdat_dtr': '8/29/2018',
#   'cmstdat_dts': '8/29/2018',
#   'cmendat': '29-Aug-18',
#   'cmendat_dtr': '8/29/2018',
#   'cmendat_dts': '8/29/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'METOCLOPRAMIDE HYDROCHLORIDE',
#   'cmdecod': 'METOCLOPRAMIDE HYDROCHLORIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 90,
#   'formindex': 576000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'PURIFIED SODIUM HYALURONATE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '23',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '52/52/2018',
#   'cmstdat_dtr': '52/52/2018',
#   'cmstdat_dts': '52/52/2018',
#   'cmendat': '',
#   'cmendat_dtr': '',
#   'cmendat_dts': '',
#   'cmongo': 'YES',
#   'cmongo_c': 'Y',
#   'cmongo_nd': '',
#   'compterm': 'PURIFIED SODIUM HYALURONATE',
#   'cmdecod': 'HYALURONATE SODIUM',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 93,
#   'formindex': 580000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'SODIUM PICOSULFATE HYDRATE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '6-Jun-18',
#   'cmstdat_dtr': '6/6/2018',
#   'cmstdat_dts': '6/6/2018',
#   'cmendat': '6-Jun-18',
#   'cmendat_dtr': '6/6/2018',
#   'cmendat_dts': '6/6/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'SODIUM PICOSULFATE HYDRATE',
#   'cmdecod': 'SODIUM PICOSULFATE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 99,
#   'formindex': 585000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'FLUOROMETHOLONE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '7/50/2018',
#   'cmstdat_dtr': '7/50/2018',
#   'cmstdat_dts': '7/50/2018',
#   'cmendat': '18-Jul-18',
#   'cmendat_dtr': '7/18/2018',
#   'cmendat_dts': '7/18/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'FLUOROMETHOLONE',
#   'cmdecod': 'FLUOROMETHOLONE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 500,
#   'formindex': 585000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'BETAMETHASONE BUTYRATE PROPIONATE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '50',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '8-Jun-18',
#   'cmstdat_dtr': '6/8/2018',
#   'cmstdat_dts': '6/8/2018',
#   'cmendat': '6/51/2018',
#   'cmendat_dtr': '6/51/2018',
#   'cmendat_dts': '6/51/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'BETAMETHASONE BUTYRATE PROPIONATE',
#   'cmdecod': 'BETAMETHASONE BUTYRATE PROPIONATE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 502,
#   'formindex': 613000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'MEROPENEM HYDRATE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '22-May-18',
#   'cmstdat_dtr': '5/22/2018',
#   'cmstdat_dts': '5/22/2018',
#   'cmendat': '23-May-18',
#   'cmendat_dtr': '5/23/2018',
#   'cmendat_dts': '5/23/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'MEROPENEM HYDRATE',
#   'cmdecod': 'MEROPENEM',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 503,
#   'formindex': 614000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '31-Jul-18',
#   'cmstdat_dtr': '7/31/2018',
#   'cmstdat_dts': '7/31/2018',
#   'cmendat': '1-Aug-18',
#   'cmendat_dtr': '8/1/2018',
#   'cmendat_dts': '8/1/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 504,
#   'formindex': 618000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '48',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '31-Jul-18',
#   'cmstdat_dtr': '7/31/2018',
#   'cmstdat_dts': '7/31/2018',
#   'cmendat': '1-Aug-18',
#   'cmendat_dtr': '8/1/2018',
#   'cmendat_dts': '8/1/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201_3',
#   'formid': 32993,
#   'formidx': 1,
#   'formindex': 584000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 8,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'DAUNORUBICIN HYDROCHLORIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '1',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': '',
#   'cmaer_c': '',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '24-Jan-19',
#   'cmstdat_dtr': '',
#   'cmstdat_dts': '1/24/2019',
#   'cmendat': '26-Jan-19',
#   'cmendat_dtr': '',
#   'cmendat_dts': '1/26/2019',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'DAUNORUBICIN HYDROCHLORIDE',
#   'cmdecod': 'DAUNORUBICIN HYDROCHLORIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201_3',
#   'formid': 32993,
#   'formidx': 2,
#   'formindex': 584000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 8,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'CYTARABINE',
#   'cmtrt_nd': '',
#   'cmrgm': '2',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': '',
#   'cmaer_c': '',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '20-Feb-19',
#   'cmstdat_dtr': '',
#   'cmstdat_dts': '2/20/2019',
#   'cmendat': '26-Feb-19',
#   'cmendat_dtr': '',
#   'cmendat_dts': '2/26/2019',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'CYTARABINE',
#   'cmdecod': 'CYTARABINE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201_3',
#   'formid': 32993,
#   'formidx': 3,
#   'formindex': 584000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 8,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'GEMTUZUMAB OZOGAMICIN',
#   'cmtrt_nd': '',
#   'cmrgm': '3',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': '',
#   'cmaer_c': '',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '28-Feb-19',
#   'cmstdat_dtr': '',
#   'cmstdat_dts': '2/28/2019',
#   'cmendat': '28-Feb-19',
#   'cmendat_dtr': '',
#   'cmendat_dts': '2/28/2019',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'GEMTUZUMAB OZOGAMICIN',
#   'cmdecod': 'GEMTUZUMAB OZOGAMICIN',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201_3',
#   'formid': 32993,
#   'formidx': 4,
#   'formindex': 584000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 8,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'GEMTUZUMAB OZOGAMICIN',
#   'cmtrt_nd': '',
#   'cmrgm': '4',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': '',
#   'cmaer_c': '',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '26-Mar-19',
#   'cmstdat_dtr': '',
#   'cmstdat_dts': '3/26/2019',
#   'cmendat': '26-Mar-19',
#   'cmendat_dtr': '',
#   'cmendat_dts': '3/26/2019',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'GEMTUZUMAB OZOGAMICIN',
#   'cmdecod': 'GEMTUZUMAB OZOGAMICIN',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201_3',
#   'formid': 32993,
#   'formidx': 5,
#   'formindex': 584000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 8,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'CYTARABINE',
#   'cmtrt_nd': '',
#   'cmrgm': '5',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': '',
#   'cmaer_c': '',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '26-Apr-19',
#   'cmstdat_dtr': '',
#   'cmstdat_dts': '4/26/2019',
#   'cmendat': '9-May-19',
#   'cmendat_dtr': '',
#   'cmendat_dts': '5/9/2019',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'CYTARABINE',
#   'cmdecod': 'CYTARABINE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201_3',
#   'formid': 32993,
#   'formidx': 6,
#   'formindex': 584000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 8,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'CYTARABINE',
#   'cmtrt_nd': '',
#   'cmrgm': '6',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': '',
#   'cmaer_c': '',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '5-Jun-19',
#   'cmstdat_dtr': '',
#   'cmstdat_dts': '6/5/2019',
#   'cmendat': '26-Jun-19',
#   'cmendat_dtr': '',
#   'cmendat_dts': '6/26/2019',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'CYTARABINE',
#   'cmdecod': 'CYTARABINE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201_3',
#   'formid': 32993,
#   'formidx': 8,
#   'formindex': 584000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 8,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'CYTARABINE',
#   'cmtrt_nd': '',
#   'cmrgm': '1',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': '',
#   'cmaer_c': '',
#   'cmdostot': None,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '24-Jan-19',
#   'cmstdat_dtr': '',
#   'cmstdat_dts': '1/24/2019',
#   'cmendat': '30-Jan-19',
#   'cmendat_dtr': '',
#   'cmendat_dts': '1/30/2019',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'CYTARABINE',
#   'cmdecod': 'CYTARABINE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 1,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'HYDROXYCARBAMIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 2000,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '17-Apr-18',
#   'cmstdat_dtr': '4/17/2018',
#   'cmstdat_dts': '4/17/2018',
#   'cmendat': '23-Apr-18',
#   'cmendat_dtr': '4/23/2018',
#   'cmendat_dts': '4/23/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'HYDROXYCARBAMIDE',
#   'cmdecod': 'HYDROXYCARBAMIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 2,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'TRAMADOL HYDROCHLORIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 50,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '20-Apr-18',
#   'cmstdat_dtr': '4/20/2018',
#   'cmstdat_dts': '4/20/2018',
#   'cmendat': '5/51/2018',
#   'cmendat_dtr': '5/51/2018',
#   'cmendat_dts': '5/51/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'TRAMADOL HYDROCHLORIDE',
#   'cmdecod': 'TRAMADOL HYDROCHLORIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 3,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'RABEPRAZOLE SODIUM',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 50,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '18-Apr-18',
#   'cmstdat_dtr': '4/18/2018',
#   'cmstdat_dts': '4/18/2018',
#   'cmendat': '18-Apr-18',
#   'cmendat_dtr': '4/18/2018',
#   'cmendat_dts': '4/18/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'RABEPRAZOLE SODIUM',
#   'cmdecod': 'RABEPRAZOLE SODIUM',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 4,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'FEBUXOSTAT',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 60,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '18-Apr-18',
#   'cmstdat_dtr': '4/18/2018',
#   'cmstdat_dts': '4/18/2018',
#   'cmendat': '23-Apr-18',
#   'cmendat_dtr': '4/23/2018',
#   'cmendat_dts': '4/23/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'FEBUXOSTAT',
#   'cmdecod': 'FEBUXOSTAT',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 5,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'MIYA BM TABLETS',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 3,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '21-Apr-18',
#   'cmstdat_dtr': '4/21/2018',
#   'cmstdat_dts': '4/21/2018',
#   'cmendat': '',
#   'cmendat_dtr': '',
#   'cmendat_dts': '',
#   'cmongo': 'YES',
#   'cmongo_c': 'Y',
#   'cmongo_nd': '',
#   'compterm': 'MIYA BM TABLETS',
#   'cmdecod': 'CLOSTRIDIUM BUTYRICUM',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 6,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'TORASEMIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 4,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '21-Apr-18',
#   'cmstdat_dtr': '4/21/2018',
#   'cmstdat_dts': '4/21/2018',
#   'cmendat': '21-Apr-18',
#   'cmendat_dtr': '4/21/2018',
#   'cmendat_dts': '4/21/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'TORASEMIDE',
#   'cmdecod': 'TORASEMIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 7,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'APREPITANT',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 525,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '24-Apr-18',
#   'cmstdat_dtr': '4/24/2018',
#   'cmstdat_dts': '4/24/2018',
#   'cmendat': '26-Apr-18',
#   'cmendat_dtr': '4/26/2018',
#   'cmendat_dts': '4/26/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'APREPITANT',
#   'cmdecod': 'APREPITANT',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 8,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'REBAMIPIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 200,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '18-Apr-18',
#   'cmstdat_dtr': '4/18/2018',
#   'cmstdat_dts': '4/18/2018',
#   'cmendat': '20-Apr-18',
#   'cmendat_dtr': '4/20/2018',
#   'cmendat_dts': '4/20/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'REBAMIPIDE',
#   'cmdecod': 'REBAMIPIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 9,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'SENNOSIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 24,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '19-Apr-18',
#   'cmstdat_dtr': '4/19/2018',
#   'cmstdat_dts': '4/19/2018',
#   'cmendat': '27-Apr-18',
#   'cmendat_dtr': '4/27/2018',
#   'cmendat_dts': '4/27/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'SENNOSIDE',
#   'cmdecod': 'SENNOSIDE A+B',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 50,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'SODIUM PICOSULFATE HYDRATE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 50,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '21-Apr-18',
#   'cmstdat_dtr': '4/21/2018',
#   'cmstdat_dts': '4/21/2018',
#   'cmendat': '27-Apr-18',
#   'cmendat_dtr': '4/27/2018',
#   'cmendat_dts': '4/27/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'SODIUM PICOSULFATE HYDRATE',
#   'cmdecod': 'SODIUM PICOSULFATE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 51,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'ACETAZOLAMIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 750,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '24-Apr-18',
#   'cmstdat_dtr': '4/24/2018',
#   'cmstdat_dts': '4/24/2018',
#   'cmendat': '1-May-18',
#   'cmendat_dtr': '5/1/2018',
#   'cmendat_dts': '5/1/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'ACETAZOLAMIDE',
#   'cmdecod': 'ACETAZOLAMIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 52,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'BAKTAR COMBINATION TABLETS',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 1,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '30-Apr-18',
#   'cmstdat_dtr': '4/30/2018',
#   'cmstdat_dts': '4/30/2018',
#   'cmendat': '28-May-18',
#   'cmendat_dtr': '5/28/2018',
#   'cmendat_dts': '5/28/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'BAKTAR COMBINATION TABLETS',
#   'cmdecod': 'SULFAMETHOXAZOLE;TRIMETHOPRIM',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 13,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'FLUCONAZOLE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 500,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '28-Apr-18',
#   'cmstdat_dtr': '4/28/2018',
#   'cmstdat_dts': '4/28/2018',
#   'cmendat': '2-May-18',
#   'cmendat_dtr': '5/2/2018',
#   'cmendat_dts': '5/2/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'FLUCONAZOLE',
#   'cmdecod': 'FLUCONAZOLE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 14,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'MAGNESIUM OXIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 990,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '25-Apr-18',
#   'cmstdat_dtr': '4/25/2018',
#   'cmstdat_dts': '4/25/2018',
#   'cmendat': '28-Apr-18',
#   'cmendat_dtr': '4/28/2018',
#   'cmendat_dts': '4/28/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'MAGNESIUM OXIDE',
#   'cmdecod': 'MAGNESIUM OXIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 53,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'PRANOPROFEN',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 8,
#   'cmdostot_nd': '',
#   'cmdosu': '',
#   'cmdosu_c': None,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '28-Apr-18',
#   'cmstdat_dtr': '4/28/2018',
#   'cmstdat_dts': '4/28/2018',
#   'cmendat': '',
#   'cmendat_dtr': '',
#   'cmendat_dts': '',
#   'cmongo': 'YES',
#   'cmongo_c': 'Y',
#   'cmongo_nd': '',
#   'compterm': 'PRANOPROFEN',
#   'cmdecod': 'PRANOPROFEN',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 16,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'ACETAMINOPHEN',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '4,13',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 5000,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '26-Apr-18',
#   'cmstdat_dtr': '4/26/2018',
#   'cmstdat_dts': '4/26/2018',
#   'cmendat': '26-Apr-18',
#   'cmendat_dtr': '4/26/2018',
#   'cmendat_dts': '4/26/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'ACETAMINOPHEN',
#   'cmdecod': 'PARACETAMOL',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 17,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'OMEPRAZOLE SODIUM',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 40,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '19-Apr-18',
#   'cmstdat_dtr': '4/19/2018',
#   'cmstdat_dts': '4/19/2018',
#   'cmendat': '24-Apr-18',
#   'cmendat_dtr': '4/24/2018',
#   'cmendat_dts': '4/24/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'OMEPRAZOLE SODIUM',
#   'cmdecod': 'OMEPRAZOLE SODIUM',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 18,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM L-ASPARTATE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 20,
#   'cmdostot_nd': '',
#   'cmdosu': 'mEq',
#   'cmdosu_c': 77,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '23-Apr-18',
#   'cmstdat_dtr': '4/23/2018',
#   'cmstdat_dts': '4/23/2018',
#   'cmendat': '23-Apr-18',
#   'cmendat_dtr': '4/23/2018',
#   'cmendat_dts': '4/23/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM L-ASPARTATE',
#   'cmdecod': 'POTASSIUM ASPARTATE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 19,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'RASBURICASE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 7,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '23-Apr-18',
#   'cmstdat_dtr': '4/23/2018',
#   'cmstdat_dts': '4/23/2018',
#   'cmendat': '23-Apr-18',
#   'cmendat_dtr': '4/23/2018',
#   'cmendat_dts': '4/23/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'RASBURICASE',
#   'cmdecod': 'RASBURICASE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 20,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'GRANISETRON HYDROCHLORIDE',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 2,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'YES',
#   'cmprior_c': 'Y',
#   'cmstdat': '24-Apr-18',
#   'cmstdat_dtr': '4/24/2018',
#   'cmstdat_dts': '4/24/2018',
#   'cmendat': '30-Apr-18',
#   'cmendat_dtr': '4/30/2018',
#   'cmendat_dts': '4/30/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'GRANISETRON HYDROCHLORIDE',
#   'cmdecod': 'GRANISETRON HYDROCHLORIDE',
#   'siteno': 14931},
#  {'studyid': 'StudyHack',
#   'siteid': 5173,
#   'subjid': 51735001,
#   'subjectid': 76809,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 21,
#   'formindex': 547000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
# ...
#   'cmstdat': '52/3/2018',
#   'cmstdat_dtr': '52/3/2018',
#   'cmstdat_dts': '52/3/2018',
#   'cmendat': '',
#   'cmendat_dtr': '',
#   'cmendat_dts': '',
#   'cmongo': 'YES',
#   'cmongo_c': 'Y',
#   'cmongo_nd': '',
#   'compterm': 'PAREPLUS',
#   'cmdecod': 'ACETYLCYSTEINE;ALANINE;ARGININE;ASCORBIC ACID;ASPARTIC ACID;BIOTIN;CALCIUM CHLORIDE DIHYDRATE;CYANOC',
#   'siteno': 14973},
#  {'studyid': 'StudyHack',
#   'siteid': 5539,
#   'subjid': 55395001,
#   'subjectid': 381416,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 57,
#   'formindex': 586000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'ACETAMINOPHEN',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '50',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 800,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '51/9/2018',
#   'cmstdat_dtr': '51/9/2018',
#   'cmstdat_dts': '51/9/2018',
#   'cmendat': '51/51/2018',
#   'cmendat_dtr': '51/51/2018',
#   'cmendat_dts': '51/51/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'ACETAMINOPHEN',
#   'cmdecod': 'PARACETAMOL',
#   'siteno': 14973},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 8,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'MELATONIN',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 3,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '27-Aug-18',
#   'cmstdat_dtr': '8/27/2018',
#   'cmstdat_dts': '8/27/2018',
#   'cmendat': '27-Aug-18',
#   'cmendat_dtr': '8/27/2018',
#   'cmendat_dts': '8/27/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'MELATONIN',
#   'cmdecod': 'MELATONIN',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 9,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE TABLET ER',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '14, 17',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 40,
#   'cmdostot_nd': '',
#   'cmdosu': 'mEq',
#   'cmdosu_c': 77,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '14-Sep-18',
#   'cmstdat_dtr': '9/14/2018',
#   'cmstdat_dts': '9/14/2018',
#   'cmendat': '14-Sep-18',
#   'cmendat_dtr': '9/14/2018',
#   'cmendat_dts': '9/14/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE TABLET ER',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 50,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE TABLET',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '53',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 40,
#   'cmdostot_nd': '',
#   'cmdosu': 'mEq',
#   'cmdosu_c': 77,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '18-Sep-18',
#   'cmstdat_dtr': '9/18/2018',
#   'cmstdat_dts': '9/18/2018',
#   'cmendat': '18-Sep-18',
#   'cmendat_dtr': '9/18/2018',
#   'cmendat_dts': '9/18/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE TABLET',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 51,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE IVPB',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '18',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 20,
#   'cmdostot_nd': '',
#   'cmdosu': 'mEq',
#   'cmdosu_c': 77,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '19-Aug-18',
#   'cmstdat_dtr': '8/19/2018',
#   'cmstdat_dts': '8/19/2018',
#   'cmendat': '19-Aug-18',
#   'cmendat_dtr': '8/19/2018',
#   'cmendat_dts': '8/19/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE IVPB',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 52,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE IVPB',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 20,
#   'cmdostot_nd': '',
#   'cmdosu': 'mEq',
#   'cmdosu_c': 77,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '25-Aug-18',
#   'cmstdat_dtr': '8/25/2018',
#   'cmstdat_dts': '8/25/2018',
#   'cmendat': '25-Aug-18',
#   'cmendat_dtr': '8/25/2018',
#   'cmendat_dts': '8/25/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE IVPB',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 13,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE IVPB',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 20,
#   'cmdostot_nd': '',
#   'cmdosu': 'mEq',
#   'cmdosu_c': 77,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '27-Aug-18',
#   'cmstdat_dtr': '8/27/2018',
#   'cmstdat_dts': '8/27/2018',
#   'cmendat': '27-Aug-18',
#   'cmendat_dtr': '8/27/2018',
#   'cmendat_dts': '8/27/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE IVPB',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 14,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE IVPB',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '16',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 20,
#   'cmdostot_nd': '',
#   'cmdosu': 'mEq',
#   'cmdosu_c': 77,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '4-Sep-18',
#   'cmstdat_dtr': '9/4/2018',
#   'cmstdat_dts': '9/4/2018',
#   'cmendat': '5-Sep-18',
#   'cmendat_dtr': '9/5/2018',
#   'cmendat_dts': '9/5/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE IVPB',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 53,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE IVPB',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 53,
#   'cmdostot_nd': '',
#   'cmdosu': 'mmol',
#   'cmdosu_c': 78,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '25-Aug-18',
#   'cmstdat_dtr': '8/25/2018',
#   'cmstdat_dts': '8/25/2018',
#   'cmendat': '25-Aug-18',
#   'cmendat_dtr': '8/25/2018',
#   'cmendat_dts': '8/25/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE IVPB',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 16,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'POTASSIUM CHLORIDE IVPB',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 53,
#   'cmdostot_nd': '',
#   'cmdosu': 'mmol',
#   'cmdosu_c': 78,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '27-Aug-18',
#   'cmstdat_dtr': '8/27/2018',
#   'cmstdat_dts': '8/27/2018',
#   'cmendat': '28-Aug-18',
#   'cmendat_dtr': '8/28/2018',
#   'cmendat_dts': '8/28/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'POTASSIUM CHLORIDE IVPB',
#   'cmdecod': 'POTASSIUM CHLORIDE',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 17,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'TRAMADOL',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '3',
#   'cmaer': 'YES',
#   'cmaer_c': 'Y',
#   'cmdostot': 25,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '29-Aug-18',
#   'cmstdat_dtr': '8/29/2018',
#   'cmstdat_dts': '8/29/2018',
#   'cmendat': '30-Aug-18',
#   'cmendat_dtr': '8/30/2018',
#   'cmendat_dts': '8/30/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'TRAMADOL',
#   'cmdecod': 'TRAMADOL',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 18,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'ACETAMINOPHEN',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 650,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '9/52/2018',
#   'cmstdat_dtr': '9/52/2018',
#   'cmstdat_dts': '9/52/2018',
#   'cmendat': '9/52/2018',
#   'cmendat_dtr': '9/52/2018',
#   'cmendat_dts': '9/52/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'ACETAMINOPHEN',
#   'cmdecod': 'PARACETAMOL',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 19,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'ACETAMINOPHEN',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 650,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '14-Sep-18',
#   'cmstdat_dtr': '9/14/2018',
#   'cmstdat_dts': '9/14/2018',
#   'cmendat': '14-Sep-18',
#   'cmendat_dtr': '9/14/2018',
#   'cmendat_dts': '9/14/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'ACETAMINOPHEN',
#   'cmdecod': 'PARACETAMOL',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 20,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'ALLOPURINOL',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 300,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '17-Aug-18',
#   'cmstdat_dtr': '8/17/2018',
#   'cmstdat_dts': '8/17/2018',
#   'cmendat': '27-Aug-18',
#   'cmendat_dtr': '8/27/2018',
#   'cmendat_dts': '8/27/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'ALLOPURINOL',
#   'cmdecod': 'ALLOPURINOL',
#   'siteno': 523266},
#  {'studyid': 'StudyHack',
#   'siteid': 5086,
#   'subjid': 50865005,
#   'subjectid': 386442,
#   'visitid': 38942,
#   'visitidx': 1,
#   'visitnam': 'AECM',
#   'formname': 'CM201',
#   'formid': 38623,
#   'formidx': 21,
#   'formindex': 565000000000000.0,
#   'cmyn': 'YES',
#   'cmyn_c': 'Y',
#   'cmcat_c': 1,
#   'cmcat_nd': '',
#   'cmscat': '',
#   'cmscat_c': '',
#   'cmpresp': 'NO',
#   'cmpresp_c': 'N',
#   'cmpresp_nd': '',
#   'cmtrt': 'ALLOPURINOL',
#   'cmtrt_nd': '',
#   'cmrgm': '',
#   'cmrgm_nd': '',
#   'cmindc': '',
#   'cmaeno': '',
#   'cmaer': 'NO',
#   'cmaer_c': 'N',
#   'cmdostot': 300,
#   'cmdostot_nd': '',
#   'cmdosu': 'mg',
#   'cmdosu_c': 8,
#   'cmdosu_nd': '',
#   'cmroute': '',
#   'cmroute_c': None,
#   'cmprior': 'NO',
#   'cmprior_c': 'N',
#   'cmstdat': '5-Sep-18',
#   'cmstdat_dtr': '9/5/2018',
#   'cmstdat_dts': '9/5/2018',
#   'cmendat': '9-Sep-18',
#   'cmendat_dtr': '9/9/2018',
#   'cmendat_dts': '9/9/2018',
#   'cmongo': 'NO',
#   'cmongo_c': 'N',
#   'cmongo_nd': '',
#   'compterm': 'ALLOPURINOL',
#   'cmdecod': 'ALLOPURINOL',
#   'siteno': 523266},
#  ...]

# %%
cm_table=pd.DataFrame(cm_data2)
cm_table
# Out:
#          studyid  siteid    subjid  subjectid  visitid  visitidx visitnam  \
# 0      StudyHack    5173  51735001      76809    38942         1     AECM
# 1      StudyHack    5173  51735001      76809    38942         1     AECM
# 2      StudyHack    5173  51735001      76809    38942         1     AECM
# 3      StudyHack    5173  51735001      76809    38942         1     AECM
# 4      StudyHack    5173  51735001      76809    38942         1     AECM
# ...          ...     ...       ...        ...      ...       ...      ...
# 42440  StudyHack    5184  51845002   55397989    38942         1     AECM
# 42441  StudyHack    5184  51845002   55397989    38942         1     AECM
# 42442  StudyHack    5184  51845002   55397989    38942         1     AECM
# 42443  StudyHack    5184  51845002   55397989    38942         1     AECM
# 42444  StudyHack    5184  51845002   55397989    38942         1     AECM
#
#       formname  formid  formidx  ...  cmstdat_dts    cmendat cmendat_dtr  \
# 0        CM201   38623       76  ...    7/14/2018   2-Sep-18    9/2/2018
# 1        CM201   38623       77  ...    8/51/2018  28-Sep-18   9/28/2018
# 2        CM201   38623       78  ...     8/8/2018  8/51/2018   8/51/2018
# 3        CM201   38623       79  ...    7/16/2018  17-Aug-18   8/17/2018
# 4        CM201   38623       80  ...     8/8/2018  13-Aug-18   8/13/2018
# ...        ...     ...      ...  ...          ...        ...         ...
# 42440    CM201   38623       20  ...    9/21/2019  25-Sep-19   9/25/2019
# 42441    CM201   38623       21  ...    9/24/2019  24-Sep-19   9/24/2019
# 42442    CM201   38623       22  ...    9/23/2019  24-Sep-19   9/24/2019
# 42443    CM201   38623       23  ...    9/24/2019  24-Sep-19   9/24/2019
# 42444    CM201   38623       24  ...    8/25/2019  25-Aug-19   8/25/2019
#
#        cmendat_dts cmongo cmongo_c cmongo_nd  \
# 0         9/2/2018     NO        N
# 1        9/28/2018     NO        N
# 2        8/51/2018     NO        N
# 3        8/17/2018     NO        N
# 4        8/13/2018     NO        N
# ...            ...    ...      ...       ...
# 42440    9/25/2019     NO        N
# 42441    9/24/2019     NO        N
# 42442    9/24/2019     NO        N
# 42443    9/24/2019     NO        N
# 42444    8/25/2019     NO        N
#
#                                           compterm  \
# 0                                    ACETAMINOPHEN
# 1      AZULENE GLUTAMINE COMBINATION FINE GRANULES
# 2                        PENTAZOCINE HYDROCHLORIDE
# 3                                           BAKTAR
# 4                               POTASSIUM CHLORIDE
# ...                                            ...
# 42440                             HYDROXYCARBAMIDE
# 42441          ONDANSETRON HYDROCHLORIDE INJECTION
# 42442                                     DEZOCINE
# 42443     DEXAMETHASONE SODIUM PHOSPHATE INJECTION
# 42444                                    LACTULOSE
#
#                               cmdecod   siteno
# 0                         PARACETAMOL    14931
# 1               AZULENE;LEVOGLUTAMIDE    14931
# 2           PENTAZOCINE HYDROCHLORIDE    14931
# 3       SULFAMETHOXAZOLE;TRIMETHOPRIM    14931
# 4                  POTASSIUM CHLORIDE    14931
# ...                               ...      ...
# 42440                HYDROXYCARBAMIDE  3259974
# 42441       ONDANSETRON HYDROCHLORIDE  3259974
# 42442                        DEZOCINE  3259974
# 42443  DEXAMETHASONE SODIUM PHOSPHATE  3259974
# 42444                       LACTULOSE  3259974
#
# [42445 rows x 49 columns]

# %%
def type1_check(ae_table, cm_table):
    first_list = []
    for cm_row in cm_table:
        for ae_row in ae_table:
            payload = {}
            payload['formname'] = "Fetch formname from cmrow"
            payload['formid'] = "Fetch formid from cmrow"
            payload['formidx'] = "Fetch formidx from cmrow"
            payload['type'] = 'TYPE1'
            payload['subjectid'] = "Fetch subjid from cmrow"
            discrepancy_list.append(payload)
            first_list.to_csv('ae,cm_info_new.csv', sep = '\t')

    return first_list

# %%
ae_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23188/3547690467.py in <module>
# ----> 1 ae_table
#
# NameError: name 'ae_table' is not defined

# %%
pwd
# Out:
# 'C:\\Users\\ELCOT\\Downloads'

# %%
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23188/4064716345.py in <module>
# ----> 1 'ae,cm_info_new.csv'.getcwd()
#
# AttributeError: 'str' object has no attribute 'getcwd'

# %%
di = os.getcwd()
print(di)
# Out:
# C:\Users\ELCOT\Downloads
