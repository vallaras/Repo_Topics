# %%
import pandas as pd

# %%
info=pd.read_csv(r"C:\Users\ELCOT\Downloads\Finaltable.csv")
info
# Out:
#                     Film  Year           Actor        Director  Box Office  \
# 0                  Dr.no  1962    Sean Connery   Terance Young       448.8
# 1  From Russia with Love  1963    Sean Connery   Terance Young       543.8
# 2             Goldfinger  1964    Sean Connery   Guy Harnilton       820.4
# 3            Thunderball  1965    David Niven    Terence Young       848.1
# 4          Casino Royale  1967    Sean Connery  Lewise Gilbert       315.0
# 5    You Only Live Twice  1967     Roger Moore       John Glen       291.5
# 6     For Your Eyes Only  1969  Timothy Dation   Guy Harnilton       442.5
# 7   Diamonds Are Forever  1971             NaN   Guy Harnilton       380.0
# 8       A view to A Kill  1973     Roger Moore   Guy Harnilton       275.2
#
#    Budget  Bond Acotor Salary
# 0     7.1                 0.8
# 1    12.6                 1.6
# 2    18.6                 3.2
# 3    41.9                 4.7
# 4    85.0                 NaN
# 5    59.9                 4.4
# ...

# %% [markdown]
# Use The set_index()

# %%
info.set_index(keys="Film",inplace=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12620/3931593129.py in <module>
# ----> 1 info.set_index(keys="Film",inplace=False)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['Film'] are in the columns"

# %%
info.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr.no                  1962  Sean Connery  Terance Young       448.8     7.1
# From Russia with Love  1963  Sean Connery  Terance Young       543.8    12.6
# Goldfinger             1964  Sean Connery  Guy Harnilton       820.4    18.6
#
#                        Bond Acotor Salary
# Film
# Dr.no                                 0.8
# From Russia with Love                 1.6
# Goldfinger                            3.2

# %% [markdown]
# reset_index

# %%
info.reset_index()
info.reset_index(drop=False)
info.reset_index(drop=True)
info.reset_index(drop=False,inplace=True)
info.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                  Dr.no  1962  Sean Connery  Terance Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terance Young       543.8
# 2             Goldfinger  1964  Sean Connery  Guy Harnilton       820.4
#
#    Budget  Bond Acotor Salary
# 0     7.1                 0.8
# 1    12.6                 1.6
# 2    18.6                 3.2

# %%
info.set_index("Film")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2128/3522727994.py in <module>
# ----> 1 info.set_index("Film")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['Film'] are in the columns"

# %%
info.set_index("Year")
# Out:
#                Actor        Director  Box Office  Budget  Bond Acotor Salary
# Year
# 1962    Sean Connery   Terance Young       448.8     7.1                 0.8
# 1963    Sean Connery   Terance Young       543.8    12.6                 1.6
# 1964    Sean Connery   Guy Harnilton       820.4    18.6                 3.2
# 1965    David Niven    Terence Young       848.1    41.9                 4.7
# 1967    Sean Connery  Lewise Gilbert       315.0    85.0                 NaN
# 1967     Roger Moore       John Glen       291.5    59.9                 4.4
# 1969  Timothy Dation   Guy Harnilton       442.5    37.3                 0.6
# 1971             NaN   Guy Harnilton       380.0    27.7                 NaN
# 1973     Roger Moore   Guy Harnilton       275.2    60.1                 5.8

# %%
info.reset_index(inplace=True)
info.set_index("Year",inplace=True)

# %%
info.head(3)
# Out:
#       index                   Film         Actor       Director  Box Office  \
# Year
# 1962      0                  Dr.no  Sean Connery  Terance Young       448.8
# 1963      1  From Russia with Love  Sean Connery  Terance Young       543.8
# 1964      2             Goldfinger  Sean Connery  Guy Harnilton       820.4
#
#       Budget  Bond Acotor Salary
# Year
# 1962     7.1                 0.8
# 1963    12.6                 1.6
# 1964    18.6                 3.2

# %% [markdown]
# Retrive Rows by index Label with .loc[] Accessor

# %%
info=pd.read_csv(r"C:\Users\ELCOT\Downloads\Finaltable.csv",index_col="Film")
info.sort_index(inplace=False)
info.head()
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Dr.no                  1962  Sean Connery   Terance Young       448.8     7.1
# From Russia with Love  1963  Sean Connery   Terance Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Harnilton       820.4    18.6
# Thunderball            1965  David Niven    Terence Young       848.1    41.9
# Casino Royale          1967  Sean Connery  Lewise Gilbert       315.0    85.0
#
#                        Bond Acotor Salary
# Film
# Dr.no                                 0.8
# From Russia with Love                 1.6
# Goldfinger                            3.2
# Thunderball                           4.7
# Casino Royale                         NaN

# %%
info.loc["A view to A Kill"]
info.loc["Dr.no"]
# Out:
# Year                           1962
# Actor                  Sean Connery
# Director              Terance Young
# Box Office                    448.8
# Budget                          7.1
# Bond Acotor Salary              0.8
# Name: Dr.no, dtype: object

# %%
info.loc["Casino Royale"]
# Out:
# Year                            1967
# Actor                   Sean Connery
# Director              Lewise Gilbert
# Box Office                     315.0
# Budget                          85.0
# Bond Acotor Salary               NaN
# Name: Casino Royale, dtype: object

# %%
info.loc["Goldfinger":"Diamonds Are Forever"]
# Out:
#                       Year           Actor        Director  Box Office  \
# Film
# Goldfinger            1964    Sean Connery   Guy Harnilton       820.4
# Thunderball           1965    David Niven    Terence Young       848.1
# Casino Royale         1967    Sean Connery  Lewise Gilbert       315.0
# You Only Live Twice   1967     Roger Moore       John Glen       291.5
# For Your Eyes Only    1969  Timothy Dation   Guy Harnilton       442.5
# Diamonds Are Forever  1971             NaN   Guy Harnilton       380.0
#
#                       Budget  Bond Acotor Salary
# Film
# Goldfinger              18.6                 3.2
# Thunderball             41.9                 4.7
# Casino Royale           85.0                 NaN
# You Only Live Twice     59.9                 4.4
# For Your Eyes Only      37.3                 0.6
# Diamonds Are Forever    27.7                 NaN

# %%
info.loc["Goldfinger":"Diamonds Are Forever":2]
# Out:
#                     Year           Actor        Director  Box Office  Budget  \
# Film
# Goldfinger          1964    Sean Connery   Guy Harnilton       820.4    18.6
# Casino Royale       1967    Sean Connery  Lewise Gilbert       315.0    85.0
# For Your Eyes Only  1969  Timothy Dation   Guy Harnilton       442.5    37.3
#
#                     Bond Acotor Salary
# Film
# Goldfinger                         3.2
# Casino Royale                      NaN
# For Your Eyes Only                 0.6

# %%
info.loc["Goldfinger":]
# Out:
#                       Year           Actor        Director  Box Office  \
# Film
# Goldfinger            1964    Sean Connery   Guy Harnilton       820.4
# Thunderball           1965    David Niven    Terence Young       848.1
# Casino Royale         1967    Sean Connery  Lewise Gilbert       315.0
# You Only Live Twice   1967     Roger Moore       John Glen       291.5
# For Your Eyes Only    1969  Timothy Dation   Guy Harnilton       442.5
# Diamonds Are Forever  1971             NaN   Guy Harnilton       380.0
# A view to A Kill      1973     Roger Moore   Guy Harnilton       275.2
#
#                       Budget  Bond Acotor Salary
# Film
# Goldfinger              18.6                 3.2
# Thunderball             41.9                 4.7
# Casino Royale           85.0                 NaN
# You Only Live Twice     59.9                 4.4
# For Your Eyes Only      37.3                 0.6
# Diamonds Are Forever    27.7                 NaN
# ...

# %%
info.loc[:"Diamonds Are Forever"]
# Out:
#                        Year           Actor        Director  Box Office  \
# Film
# Dr.no                  1962    Sean Connery   Terance Young       448.8
# From Russia with Love  1963    Sean Connery   Terance Young       543.8
# Goldfinger             1964    Sean Connery   Guy Harnilton       820.4
# Thunderball            1965    David Niven    Terence Young       848.1
# Casino Royale          1967    Sean Connery  Lewise Gilbert       315.0
# You Only Live Twice    1967     Roger Moore       John Glen       291.5
# For Your Eyes Only     1969  Timothy Dation   Guy Harnilton       442.5
# Diamonds Are Forever   1971             NaN   Guy Harnilton       380.0
#
#                        Budget  Bond Acotor Salary
# Film
# Dr.no                     7.1                 0.8
# From Russia with Love    12.6                 1.6
# Goldfinger               18.6                 3.2
# Thunderball              41.9                 4.7
# Casino Royale            85.0                 NaN
# ...

# %%
info.loc[["Goldfinger","Diamonds Are Forever"]]
# Out:
#                       Year         Actor       Director  Box Office  Budget  \
# Film
# Goldfinger            1964  Sean Connery  Guy Harnilton       820.4    18.6
# Diamonds Are Forever  1971           NaN  Guy Harnilton       380.0    27.7
#
#                       Bond Acotor Salary
# Film
# Goldfinger                           3.2
# Diamonds Are Forever                 NaN

# %%
"Dr.no" in info.index
# Out:
# True

# %% [markdown]
# Retrieve Rows by Index Position With iloc Accessor

# %%
info=pd.read_csv(r"C:\Users\ELCOT\Downloads\Finaltable.csv")
info.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                  Dr.no  1962  Sean Connery  Terance Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terance Young       543.8
# 2             Goldfinger  1964  Sean Connery  Guy Harnilton       820.4
#
#    Budget  Bond Acotor Salary
# 0     7.1                 0.8
# 1    12.6                 1.6
# 2    18.6                 3.2

# %%
info.iloc[[0,3]]
# Out:
#           Film  Year         Actor       Director  Box Office  Budget  \
# 0        Dr.no  1962  Sean Connery  Terance Young       448.8     7.1
# 3  Thunderball  1965  David Niven   Terence Young       848.1    41.9
#
#    Bond Acotor Salary
# 0                 0.8
# 3                 4.7

# %%
info.iloc[[2,4]]
# Out:
#             Film  Year         Actor        Director  Box Office  Budget  \
# 2     Goldfinger  1964  Sean Connery   Guy Harnilton       820.4    18.6
# 4  Casino Royale  1967  Sean Connery  Lewise Gilbert       315.0    85.0
#
#    Bond Acotor Salary
# 2                 3.2
# 4                 NaN

# %%
info.iloc[2:5]
# Out:
#             Film  Year         Actor        Director  Box Office  Budget  \
# 2     Goldfinger  1964  Sean Connery   Guy Harnilton       820.4    18.6
# 3    Thunderball  1965  David Niven    Terence Young       848.1    41.9
# 4  Casino Royale  1967  Sean Connery  Lewise Gilbert       315.0    85.0
#
#    Bond Acotor Salary
# 2                 3.2
# 3                 4.7
# 4                 NaN

# %%
info.iloc[0]
info.iloc[0:1]
info.iloc[:4]
info.iloc[2:]
# Out:
#                    Film  Year           Actor        Director  Box Office  \
# 2            Goldfinger  1964    Sean Connery   Guy Harnilton       820.4
# 3           Thunderball  1965    David Niven    Terence Young       848.1
# 4         Casino Royale  1967    Sean Connery  Lewise Gilbert       315.0
# 5   You Only Live Twice  1967     Roger Moore       John Glen       291.5
# 6    For Your Eyes Only  1969  Timothy Dation   Guy Harnilton       442.5
# 7  Diamonds Are Forever  1971             NaN   Guy Harnilton       380.0
# 8      A view to A Kill  1973     Roger Moore   Guy Harnilton       275.2
#
#    Budget  Bond Acotor Salary
# 2    18.6                 3.2
# 3    41.9                 4.7
# 4    85.0                 NaN
# 5    59.9                 4.4
# 6    37.3                 0.6
# 7    27.7                 NaN
# 8    60.1                 5.8

# %% [markdown]
# Second Arguments to loc and iloc Accessors

# %%
info=pd.read_csv(r"C:\Users\ELCOT\Downloads\Finaltable.csv",index_col="Film")
info.sort_index(inplace=True)
info.head(3)
# Out:
#                       Year         Actor        Director  Box Office  Budget  \
# Film
# A view to A Kill      1973   Roger Moore   Guy Harnilton       275.2    60.1
# Casino Royale         1967  Sean Connery  Lewise Gilbert       315.0    85.0
# Diamonds Are Forever  1971           NaN   Guy Harnilton       380.0    27.7
#
#                       Bond Acotor Salary
# Film
# A view to A Kill                     5.8
# Casino Royale                        NaN
# Diamonds Are Forever                 NaN

# %%
info.loc["Casino Royale","Box Office"]
# Out:
# 315.0

# %%
info.loc[["Casino Royale","A view to A Kill"],["Box Office","Budget"]]
# Out:
#                   Box Office  Budget
# Film
# Casino Royale          315.0    85.0
# A view to A Kill       275.2    60.1

# %%
info.loc["Casino Royale","Box Office":"Bond Acotor Salary"]
# Out:
# Box Office            315.0
# Budget                 85.0
# Bond Acotor Salary      NaN
# Name: Casino Royale, dtype: object

# %%
info.loc["Goldfinger":"Diamonds Are Forever","Actor":"Bond Acotor Salary"]
# Out:
# Empty DataFrame
# Columns: [Actor, Director, Box Office, Budget, Bond Acotor Salary]
# Index: []

# %%
info.loc["Goldfinger":,"Director":]
info.loc[:"A view to A Kill",:"Budget"]
# Out:
#                   Year        Actor       Director  Box Office  Budget
# Film
# A view to A Kill  1973  Roger Moore  Guy Harnilton       275.2    60.1

# %%
info.iloc[2,2:5]
info.iloc[2:4,[2,5]]
info.iloc[[1,4],[2,5]]
info.iloc[:5,[2,3]]
info.iloc[:4,:5]
# Out:
#                       Year         Actor        Director  Box Office  Budget
# Film
# A view to A Kill      1973   Roger Moore   Guy Harnilton       275.2    60.1
# Casino Royale         1967  Sean Connery  Lewise Gilbert       315.0    85.0
# Diamonds Are Forever  1971           NaN   Guy Harnilton       380.0    27.7
# Dr.no                 1962  Sean Connery   Terance Young       448.8     7.1

# %% [markdown]
# Set New Value for a specific Cell

# %%
info=pd.read_csv(r"C:\Users\ELCOT\Downloads\Finaltable.csv",index_col="Film")
info.sort_index(inplace=True)
info.head(3)
# Out:
#                       Year         Actor        Director  Box Office  Budget  \
# Film
# A view to A Kill      1973   Roger Moore   Guy Harnilton       275.2    60.1
# Casino Royale         1967  Sean Connery  Lewise Gilbert       315.0    85.0
# Diamonds Are Forever  1971           NaN   Guy Harnilton       380.0    27.7
#
#                       Bond Acotor Salary
# Film
# A view to A Kill                     5.8
# Casino Royale                        NaN
# Diamonds Are Forever                 NaN

# %%
info.loc["A view to A Kill","Actor"]="Selvaragavan"
info.loc["A view to A Kill","Actor"]
# Out:
# 'Selvaragavan'

# %%
info.loc["A view to A Kill",["Box Office","Budget","Bond Acotor Salary"]]=[1000,100000,2500000]

# %%
info.loc["A view to A Kill",["Box Office","Bond Acotor Salary"]]
# Out:
# Box Office               1000.0
# Bond Acotor Salary    2500000.0
# Name: A view to A Kill, dtype: object

# %% [markdown]
# Set Multiple Values in DataFrame

# %%
info=pd.read_csv(r"C:\Users\ELCOT\Downloads\Finaltable.csv",index_col="Film")
info.sort_index(inplace=True)
info.head(3)
# Out:
#                       Year         Actor        Director  Box Office  Budget  \
# Film
# A view to A Kill      1973   Roger Moore   Guy Harnilton       275.2    60.1
# Casino Royale         1967  Sean Connery  Lewise Gilbert       315.0    85.0
# Diamonds Are Forever  1971           NaN   Guy Harnilton       380.0    27.7
#
#                       Bond Acotor Salary
# Film
# A view to A Kill                     5.8
# Casino Royale                        NaN
# Diamonds Are Forever                 NaN

# %%
info["Actor"]="Sean Connery"
info["Actor"]=="Sean Connery"
# Out:
# Film
# A view to A Kill         True
# Casino Royale            True
# Diamonds Are Forever     True
# Dr.no                    True
# For Your Eyes Only       True
# From Russia with Love    True
# Goldfinger               True
# Thunderball              True
# You Only Live Twice      True
# Name: Actor, dtype: bool

# %%
fst_sean=info["Actor"]=="Sean Connery"
info[fst_sean]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# A view to A Kill       1973  Sean Connery   Guy Harnilton       275.2    60.1
# Casino Royale          1967  Sean Connery  Lewise Gilbert       315.0    85.0
# Diamonds Are Forever   1971  Sean Connery   Guy Harnilton       380.0    27.7
# Dr.no                  1962  Sean Connery   Terance Young       448.8     7.1
# For Your Eyes Only     1969  Sean Connery   Guy Harnilton       442.5    37.3
# From Russia with Love  1963  Sean Connery   Terance Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Harnilton       820.4    18.6
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery       John Glen       291.5    59.9
#
#                        Bond Acotor Salary
# Film
# A view to A Kill                      5.8
# Casino Royale                         NaN
# Diamonds Are Forever                  NaN
# ...

# %%
info.loc[fst_sean]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# A view to A Kill       1973  Sean Connery   Guy Harnilton       275.2    60.1
# Casino Royale          1967  Sean Connery  Lewise Gilbert       315.0    85.0
# Diamonds Are Forever   1971  Sean Connery   Guy Harnilton       380.0    27.7
# Dr.no                  1962  Sean Connery   Terance Young       448.8     7.1
# For Your Eyes Only     1969  Sean Connery   Guy Harnilton       442.5    37.3
# From Russia with Love  1963  Sean Connery   Terance Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Harnilton       820.4    18.6
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery       John Glen       291.5    59.9
#
#                        Bond Acotor Salary
# Film
# A view to A Kill                      5.8
# Casino Royale                         NaN
# Diamonds Are Forever                  NaN
# ...

# %%
info.loc[fst_sean,"Actor"]=="Sir Sean Connery"
# Out:
# Film
# A view to A Kill         False
# Casino Royale            False
# Diamonds Are Forever     False
# Dr.no                    False
# For Your Eyes Only       False
# From Russia with Love    False
# Goldfinger               False
# Thunderball              False
# You Only Live Twice      False
# Name: Actor, dtype: bool
